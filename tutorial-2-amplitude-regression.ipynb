# %% [markdown]
# # Amplitude regression

# %% [markdown]
# In the lectures you've covered multi-variate analyses, fits and interpolations, and the basics of neural networks.  Here we'll put this into practice by building a neural network in pytorch to perform a regression task on the LHC amplitude for the production of two photons and a gluon in a gluon-gluon collision.

# %% [markdown]
# We want to train a network to predict the amplitude for the process $gg\rightarrow\gamma\gamma g$.  So the amplitude depends on the 4-momentum of 5 particles: 2 incoming gluons, 2 outgoing photons, and one outgoing gluon.
#
# The incoming gluons will have no transverse momentum, but their total momentum along the beam pipe is not necessarily zero.
#
# The network we will train is a simple fully connected dense network.  This means that the input and output can only be vectors of real numbers.  We want to input the kinematic information on the particles to the network, and train the network to output the corresponding amplitude.  So we need to think about how we input our kinematic 4-vectors to the network, this generally depends on the network architecture we are using.

# %% [markdown]
# #### Outline / tasks:
#  - Imports \& plotting set-up
#  - Loading the data
#  - Visualising the data
#      - visualise some of the kinematics of the process (transverse momentum of photons/gluons, MET)
#      - histogram the amplitudes
#  - Preprocessing the data
#      - neural networks like $\mathcal{O}(1)$ numbers
#      - how should we preprocess the data?
#  - Datasets and dataloaders
#      - details are in the pytorch docs
#  - Building the neural network
#      - construct a cimple neural network with 2 hidden layers with some number of nodes, it's up to you
#      - tip: use linear layers followed by relu activations
#      - all the relevant details are in the pytorch docs
#  - Optimising (training) the neural network
#      - create a function to train the network for a single epoch
#      - create functions to compute the test and validation loss at the end of an epoch
#      - define a loss function (tip: MSE is a good choice)
#      - define an optimizer (tip: Adam is a good choice)
#      - train the network for some number of epochs
#  - Plot the train and validation losses as a function of the epochs
#      - to check the the network is training we should plot the train and validation losses as a function of the epochs
#  - Study the results
#      - beyond the losses, how can we check that our network is making sensible predictions?
#  - Can you think of ways to improve your network or your training?  List them!
#
# Most practical pytorch skills you need for this work is covered in the basics tutorial at https://pytorch.org/tutorials/beginner/basics/intro.html.

# %% [markdown]
# ### Imports

# %%
import os
import sys
import random
import time
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import nn

# %% [markdown]
# #### Plotting set-up

# %%
from matplotlib import pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
from matplotlib.lines import Line2D
from matplotlib.font_manager import FontProperties
import matplotlib.colors as mcolors
import colorsys

labelfont = FontProperties()
labelfont.set_family('serif')
labelfont.set_name('Times New Roman')
labelfont.set_size(14)

axislabelfont = FontProperties()
axislabelfont.set_family('serif')
axislabelfont.set_name('Times New Roman')
axislabelfont.set_size(22)

tickfont = FontProperties()
tickfont.set_family('serif')
tickfont.set_name('Times New Roman')
tickfont.set_size(16)

axisfontsize = 16
labelfontsize = 16

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams['text.usetex'] = True

# %% [markdown]
# ## Loading the data

# %%
trn_dat = np.load( "tutorial-2-data/trn_dat.npy" )
trn_amp = np.load( "tutorial-2-data/trn_amp.npy" )

val_dat = np.load( "tutorial-2-data/val_dat.npy" )
val_amp = np.load( "tutorial-2-data/val_amp.npy" )

tst_dat = np.load( "tutorial-2-data/tst_dat.npy" )
tst_amp = np.load( "tutorial-2-data/tst_amp.npy" )

# %%
print( f"train data shape: {trn_dat.shape}" )
print( f"train amp  shape: {trn_amp.shape}" )
print( f"test  data shape: {tst_dat.shape}" )
print( f"test  amp  shape: {tst_amp.shape}" )
print( f"val   data shape: {val_dat.shape}" )
print( f"val   amp  shape: {val_amp.shape}" )
# Out:
# train data shape: (30000, 5, 4)
# train amp  shape: (30000,)
# test  data shape: (30000, 5, 4)
# test  amp  shape: (30000,)
# val   data shape: (30000, 5, 4)
# val   amp  shape: (30000,)

# %% [markdown]
# The data is organised as follows:
#  - the shape corresponds to ( number of events, number of particles, 4-momentum )
#  - the particles are arranged as follows
#      - the first two entries are the two incoming gluons
#      - the next two particles are the outgoing photons
#      - the last particle is the outgoing gluon
#  - the incoming gluons and incoming photons are arranged by transverse memontum $p_T$

# %% [markdown]
# Why is the ordering important?

# %% [markdown]
# ## Visualising the data

# %% [markdown]
# Below we will make some kinematic plots of the events in the training sample.  Note however that these are not the physical distributions we would measure at the LHC!  In our training data each of these events is associated with an amplitude, which tells us the probability that the event will be produced in the gluon-gluon interaction.  So to get the physical distributions these events would need to be 'weighted' by their amplitude.  However, right now we just want to visualise our training dataset to see what preprocessing we should do.

# %%
def get_init_pz( ev ):
    return ev[0][3] + ev[1][3]

def get_mass( fv ):
    msq = np.round( fv[0]**2 - fv[1]**2 - fv[2]**2 - fv[3]**2 , 5 )
    if msq>0:
        return np.sqrt( msq )
    elif msq<0:
        raise Exception( "mass squared is less than zero" ) 
    else:
        return 0
    
def get_pt( fv ):
    ptsq = np.round( fv[1]**2 + fv[2]**2 , 5 )
    if ptsq>0:
        return np.sqrt( ptsq )
    elif ptsq<0:
        raise Exception( "$p_T$ squared is less than zero" ) 
    else:
        return 0
    
def get_met( ev ):
    return np.abs( np.sum( [ fv[1]+fv[2] for fv in ev ] ) )

# %% [markdown]
# Plotting the initial $p_z$ of the events in the training sample.

# %%
trn_dat_init_pz = []
for ev in trn_dat:
    trn_dat_init_pz.append( get_init_pz( ev ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_init_pz, histtype='stepfilled', fill=None )

axs.set_xlabel( "initial $p_z$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# We can plot a histogram of the amplitudes for the training data.

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_amp, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )
axs.set_xscale( 'log' )

axs.set_xlabel( "train amplitudes", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The amplitudes span about 4 orders of magnitude...

# %% [markdown]
# Plotting the leading photon $p_T$.

# %%
trn_dat_leading_photon_pt = []
for ev in trn_dat:
    trn_dat_leading_photon_pt.append( get_pt( ev[2] ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_leading_photon_pt, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "leading photon $p_T$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# Plot the final state gluon $p_T$.

# %%
trn_dat_gluon_pt = []
for ev in trn_dat:
    trn_dat_gluon_pt.append( get_pt( ev[4] ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_gluon_pt, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "leading gluon $p_T$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The mean final state gluon $p_T$ in GeV is:

# %%
np.mean( trn_dat_gluon_pt )
# Out:
# 49.698076969543024

# %% [markdown]
# Plotting the missing transverse energy (MET) for each event.

# %%
trn_dat_met = []
for ev in trn_dat:
    trn_dat_met.append( get_met( ev ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_met, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "MET (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# As expected, this is zero for all events (except one, oddly).  We expect this because the incoming gluons have no $p_T$.
#
# Let's see where this single high MET event arises...

# %%
np.where( np.array(trn_dat_met) > 300 )
# Out:
# (array([12127]),)

# %%
trn_dat[12127]
# Out:
# array([[ 360.37961003,   96.31550214,  192.63100427,  288.94650641],
#        [ 693.71294336, -185.40258277, -370.80516555, -556.20774832],
#        [ 506.22226952, -340.95585115, -332.00806946, -172.57095798],
#        [ 360.29766015,  277.8398014 ,  214.67663535,   80.82939381],
#        [ 187.57262372,  -25.97103088,  -60.84272717, -175.51967775]])

# %% [markdown]
# The incoming gluons are not along the beampipe.  This is a bug in the dataset. 1/30k is not such a big deal.

# %%
[ get_mass( x ) for x in trn_dat[12127] ]
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# At least the constituents are massless..

# %% [markdown]
# ## Preprocessing the data

# %% [markdown]
# We will be using a dense network, so the data needs to be in vector format.  We will collapse the data for each event to a single vector of dimension $5\times4=20$.  The fact that the data is ordered here is important.  To predict the amplitude given the kinematics, the network needs to know which entries correspond to which particles in the process.

# %%
nev = trn_dat.shape[0]
trn_datf = np.reshape( trn_dat, (nev,-1) )
val_datf = np.reshape( val_dat, (nev,-1) )
tst_datf = np.reshape( tst_dat, (nev,-1) )

# %% [markdown]
# Check the shape:

# %%
trn_datf.shape
# Out:
# (30000, 20)

# %% [markdown]
# There are further preprocessing steps we can take.  For example, the inputs are numerically very large $\mathcal{O}(100)$ and span a large range.  So we could re-scale the inputs by a constant number, or even take the logarithm of the inputs.
#
# For now, we'll just re-scale by a constant number, the average final state gluon $p_T$, assuming that this is a natural scale for the problem.  And we should be careful to preprocess the train, validation, and test data in the exact same way.

# %%
gpt = np.mean( trn_dat_gluon_pt )
trn_datf = trn_datf / gpt
val_datf = val_datf / gpt
tst_datf = tst_datf / gpt

# %% [markdown]
# Now convert them to pytorch tensors.

# %%
trn_datfp = torch.Tensor( trn_datf )
val_datfp = torch.Tensor( val_datf )
tst_datfp = torch.Tensor( tst_datf )

# %% [markdown]
# We should also preprocess the amplitude data.  As we seen in a plot above, the amplitudes span about 4 orders of magnitude.  This could be difficult for the network to interpolate.  We can aleviate the problem with preprocessing, taking the logarithm of the amplitudes.

# %%
trn_ampl = np.log( trn_amp )
val_ampl = np.log( val_amp )
tst_ampl = np.log( tst_amp )

# %%
trn_amplp = torch.Tensor( trn_ampl )
val_amplp = torch.Tensor( val_ampl )
tst_amplp = torch.Tensor( tst_ampl )

# %%
torch.mean( val_amplp )
# Out:
# tensor(-14.7285)

# %% [markdown]
# The new distribution looks nicer:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_ampl, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# ## Datasets and dataloaders

# %% [markdown]
# First define a class for the datasets.

# %%
class amp_dataset( Dataset ):
    
    def __init__( self, data, amp ):
        self.data = data
        self.amp = amp

    def __len__(self):
        return len(self.amp)

    def __getitem__(self, idx):
        return self.data[idx], self.amp[idx]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e62aa7502331> in <module>
# ----> 1 class amp_dataset( Dataset ):
#       2
#       3     def __init__( self, data, labels ):
#       4         self.data = data
#       5         self.labels = amp
#
# NameError: name 'Dataset' is not defined

# %% [markdown]
# Then initialise them with the data and amplitudes.  We use unsqueeze here so that the shape of the amplitudes matches the shape output from the neural network.

# %%
trn_dataset = amp_dataset( trn_datfp, trn_amplp.unsqueeze(-1) )
val_dataset = amp_dataset( val_datfp, val_amplp.unsqueeze(-1) )
tst_dataset = amp_dataset( tst_datfp, tst_amplp.unsqueeze(-1) )

# %% [markdown]
# Now we can define a dataloader for each of these datasets.

# %%
trn_dataloader = DataLoader( trn_dataset, batch_size=64, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=64, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=64, shuffle=True )

# %% [markdown]
# We can test our dataloader.

# %%
next( iter( trn_dataloader ) )
# Out:
# [tensor([[ 2.8816,  0.0000,  0.0000,  ...,  0.6112, -0.3550,  0.5999],
#          [ 2.3153,  0.0000,  0.0000,  ...,  0.1708, -0.5872, -0.0201],
#          [ 2.5690,  0.0000,  0.0000,  ...,  0.4198,  0.1597,  0.3769],
#          ...,
#          [ 3.0563,  0.0000,  0.0000,  ..., -0.6434, -0.7824,  1.2292],
#          [ 3.9494,  0.0000,  0.0000,  ...,  0.1623, -0.3764, -0.3846],
#          [ 4.4599,  0.0000,  0.0000,  ..., -0.6662,  0.1895, -0.1040]]),
#  tensor([[-14.6502],
#          [-14.5232],
#          [-13.8540],
#          [-15.1170],
#          [-16.5711],
#          [-13.7349],
#          [-14.8368],
#          [-16.5965],
#          [-13.9533],
#          [-14.7876],
#          [-14.3227],
#          [-14.0853],
#          [-14.3486],
#          [-16.5282],
#          [-15.5579],
#          [-14.4537],
#          [-15.4855],
#          [-14.1267],
#          [-14.7944],
#          [-15.2783],
#          [-16.0028],
#          [-14.0634],
#          [-14.7673],
#          [-14.8202],
#          [-17.9572],
#          [-15.3081],
#          [-14.2460],
#          [-12.5927],
#          [-13.8406],
#          [-15.1820],
#          [-14.6690],
#          [-15.0741],
#          [-15.0126],
#          [-13.1018],
#          [-14.8142],
#          [-14.8971],
#          [-15.1378],
#          [-17.4622],
#          [-15.4496],
#          [-13.6694],
#          [-14.5297],
#          [-16.1989],
#          [-15.3053],
#          [-13.4860],
#          [-13.8332],
#          [-14.9283],
#          [-12.8851],
#          [-14.2626],
#          [-13.6601],
#          [-12.9076],
#          [-13.9536],
#          [-15.1974],
#          [-14.4731],
#          [-13.9128],
#          [-15.6887],
#          [-15.4199],
#          [-13.3904],
#          [-11.9244],
#          [-14.7129],
#          [-15.1289],
#          [-14.3357],
#          [-15.4427],
#          [-12.5851],
#          [-13.5973]])]

# %% [markdown]
# And we can check that the shape for the kinematic data and amplitudes come out correct.

# %%
next( iter( trn_dataloader ) )[0].shape
# Out:
# torch.Size([64, 20])

# %%
next( iter( trn_dataloader ) )[1].shape
# Out:
# torch.Size([64, 1])

# %% [markdown]
# ## Building the neural network

# %% [markdown]
# We'll build a simple network with one input and one output layer, and two hidden layers.  We define the dimensions of these layers below.

# %%
ipt_dim = 20
opt_dim = 1
hdn_dim = 30

# %% [markdown]
# Now we build a very simple class for our neural network, which we call amp_net.

# %%
class amp_net( nn.Module ):
    
    # default hdn_dim is 30, but can be changed upon initialisation
    def __init__( self, hdn_dim=30 ):
        
        super( amp_net, self ).__init__()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear( ipt_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, opt_dim ),
        )

    def forward( self, x ):
        out = self.linear_relu_stack( x )
        return out

# %% [markdown]
# Check if we have a GPU.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# Initialise the neural network and send to the GPU if we have one.  We can also print the model to see what layers it has.

# %%
model = amp_net( hdn_dim=hdn_dim ).to(device)
print(model)
# Out:
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=30, out_features=30, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=30, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# Now we can test it briefly by throwing some random numbers into it.

# %%
X = torch.rand(40, 20, device=device)
model( X )
# Out:
# tensor([[0.1825],
#         [0.1734],
#         [0.1808],
#         [0.1853],
#         [0.1676],
#         [0.1868],
#         [0.1813],
#         [0.1932],
#         [0.1754],
#         [0.1695],
#         [0.1762],
#         [0.1750],
#         [0.1636],
#         [0.1782],
#         [0.1822],
#         [0.1655],
#         [0.1846],
#         [0.1623],
#         [0.1813],
#         [0.1789],
#         [0.1950],
#         [0.1693],
#         [0.1761],
#         [0.1706],
#         [0.1742],
#         [0.1855],
#         [0.1728],
#         [0.1954],
#         [0.1744],
#         [0.1803],
#         [0.1875],
#         [0.1757],
#         [0.1819],
#         [0.1798],
#         [0.1672],
#         [0.1709],
#         [0.1761],
#         [0.1624],
#         [0.1752],
#         [0.1731]], grad_fn=<AddmmBackward0>)

# %%
model( X ).shape
# Out:
# torch.Size([40, 1])

# %% [markdown]
# Looks like it's working.

# %% [markdown]
# ## Optimising (training) the neural network

# %% [markdown]
# We need to decide what function we want the neural network to optimise, i.e. the loss function.  There are a number of choices to decide from, the key point is that the loss function should be minimised when the neural network correctly predicts the amplitude given the kinematical information on the event.  For this we'll use the MSE, the mean squared error.
#
# $\text{MSE} = ( \text{pred_amp} - \text{true_amp} )^2 $

# %%
loss_fn = nn.MSELoss()

# %% [markdown]
# PyTorch will compute gradients of this loss function with respect to the trainable parameters of the network.  The network is optimised by updating the parameters using the gradients.  The exact scheme to do this is defined by our choice of optimiser.  A standard choice is the Adam optimiser, which we will use here with it's default hyper-parameters.
#
# You can read more about this optimiser here:
#  - https://pytorch.org/docs/stable/generated/torch.optim.Adam.html
#  - https://arxiv.org/abs/1412.6980

# %%
learning_rate = 1e-3
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate )

# %% [markdown]
# We've already set the batch size when defining the dataloaders.  Below we set the number of epochs, i.e. the number of times we will iterate through the training data to optimise the network.  This means that the total number of updates to the network parameters will be $\simeq\text{size of dataset}\times \text{epochs} / \text{batch size}$.

# %% [markdown]
# Now we can write a training loop for a single epoch.

# %%
def train_epoch( dataloader, model, loss_fn, optimizer ):
    
    size = len( dataloader.dataset )
    
    for batch, (X, y) in enumerate(dataloader):

        # pass data through network
        pred = model(X)
        
        # compute loss
        loss = loss_fn( pred, y )

        # reset gradients in optimizer
        optimizer.zero_grad()
        
        # compute gradients
        loss.backward()
        
        # update weights with optimizer
        optimizer.step()
        
        # print the training loss every 100 updates
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print( f"current batch loss: {loss:>7f}  [{current:>5d}/{size:>5d}]" )

# %% [markdown]
# To monitor the performance of the network on the regression task we want to calculate the loss of both the training data and the validation data on the same network, so we have the following functions:

# %%
def val_pass( dataloader, model, loss_fn ):
    
    size = len( dataloader.dataset )
    num_batches = len( dataloader )
    vl = 0.0

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            pred = model( X )
            vl += loss_fn( pred, y ).item()

    vl /= num_batches
    print( f"avg val loss per batch: {vl:>8f}" )
    
    return vl

def trn_pass( dataloader, model, loss_fn ):
    
    size = len( dataloader.dataset )
    num_batches = len( dataloader )
    tl = 0.0

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            pred = model( X )
            tl += loss_fn( pred, y ).item()

    tl /= num_batches
    print( f"avg trn loss per batch: {tl:>8f}" )
    
    return tl

# %% [markdown]
# Now we can train the model!

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# reset some parameters
batch_size = 128
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 150

# re-initialise the model and the optimizer
hdn_dim = 50
model = amp_net( hdn_dim=hdn_dim ).to(device)
learning_rate = 5e-4
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate )
seperator()
print( "model architecture ")
seperator()
print( model )

# track train and val losses
trn_losses = []
val_losses = []

for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model, loss_fn, optimizer )
    seperator()
    trn_loss = trn_pass( trn_dataloader, model, loss_fn )
    trn_losses.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model, loss_fn )
    val_losses.append( val_loss )
    seperator()
    print( "|" )
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 212.772018  [    0/30000]
# current batch loss: 50.464870  [12800/30000]
# current batch loss: 33.328609  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 26.408169
# -----------------------------------------------
# avg val loss per batch: 26.735322
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 23.978594  [    0/30000]
# current batch loss: 22.405472  [12800/30000]
# current batch loss: 5.738361  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 5.402309
# -----------------------------------------------
# avg val loss per batch: 5.645480
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 7.169126  [    0/30000]
# current batch loss: 1.442149  [12800/30000]
# current batch loss: 0.954534  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.951631
# -----------------------------------------------
# avg val loss per batch: 1.006117
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 0.918671  [    0/30000]
# current batch loss: 0.463187  [12800/30000]
# current batch loss: 0.407044  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.508788
# -----------------------------------------------
# avg val loss per batch: 0.520059
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 0.436262  [    0/30000]
# current batch loss: 0.404785  [12800/30000]
# current batch loss: 0.385448  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.419192
# -----------------------------------------------
# avg val loss per batch: 0.424289
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 0.460732  [    0/30000]
# current batch loss: 0.370703  [12800/30000]
# current batch loss: 0.671219  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.386611
# -----------------------------------------------
# avg val loss per batch: 0.387985
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 0.368572  [    0/30000]
# current batch loss: 0.393482  [12800/30000]
# current batch loss: 0.509301  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.374447
# -----------------------------------------------
# avg val loss per batch: 0.377059
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 0.392203  [    0/30000]
# current batch loss: 0.395101  [12800/30000]
# current batch loss: 0.327550  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.347642
# -----------------------------------------------
# avg val loss per batch: 0.349280
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 0.581653  [    0/30000]
# current batch loss: 0.346401  [12800/30000]
# current batch loss: 0.336475  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.340134
# -----------------------------------------------
# avg val loss per batch: 0.340847
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 0.384120  [    0/30000]
# current batch loss: 0.394314  [12800/30000]
# current batch loss: 0.363584  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.322745
# -----------------------------------------------
# avg val loss per batch: 0.326135
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 0.306473  [    0/30000]
# current batch loss: 0.392789  [12800/30000]
# current batch loss: 0.496028  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.313357
# -----------------------------------------------
# avg val loss per batch: 0.317691
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 0.274028  [    0/30000]
# current batch loss: 0.405220  [12800/30000]
# current batch loss: 0.221635  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.297807
# -----------------------------------------------
# avg val loss per batch: 0.298522
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 0.359280  [    0/30000]
# current batch loss: 0.255230  [12800/30000]
# current batch loss: 0.230481  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.285180
# -----------------------------------------------
# avg val loss per batch: 0.287946
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 0.249497  [    0/30000]
# current batch loss: 0.227595  [12800/30000]
# current batch loss: 0.222076  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.277890
# -----------------------------------------------
# avg val loss per batch: 0.280024
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 0.262757  [    0/30000]
# current batch loss: 0.349446  [12800/30000]
# current batch loss: 0.211020  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.256253
# -----------------------------------------------
# avg val loss per batch: 0.258054
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 0.216418  [    0/30000]
# current batch loss: 0.276766  [12800/30000]
# current batch loss: 0.229542  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.244105
# -----------------------------------------------
# avg val loss per batch: 0.244025
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 0.272647  [    0/30000]
# current batch loss: 0.209483  [12800/30000]
# current batch loss: 0.225028  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.228236
# -----------------------------------------------
# avg val loss per batch: 0.227488
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 0.296777  [    0/30000]
# current batch loss: 0.252584  [12800/30000]
# current batch loss: 0.256073  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.225554
# -----------------------------------------------
# avg val loss per batch: 0.226361
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 0.171206  [    0/30000]
# current batch loss: 0.191564  [12800/30000]
# current batch loss: 0.224916  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.210853
# -----------------------------------------------
# avg val loss per batch: 0.211649
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 0.173229  [    0/30000]
# current batch loss: 0.195914  [12800/30000]
# current batch loss: 0.221977  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.201385
# -----------------------------------------------
# avg val loss per batch: 0.201948
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 0.182521  [    0/30000]
# current batch loss: 0.183488  [12800/30000]
# current batch loss: 0.257052  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.197022
# -----------------------------------------------
# avg val loss per batch: 0.196397
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 0.204889  [    0/30000]
# current batch loss: 0.193025  [12800/30000]
# current batch loss: 0.206357  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.186113
# -----------------------------------------------
# avg val loss per batch: 0.184860
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 0.241295  [    0/30000]
# current batch loss: 0.171606  [12800/30000]
# current batch loss: 0.193941  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.181307
# -----------------------------------------------
# avg val loss per batch: 0.180711
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 0.154245  [    0/30000]
# current batch loss: 0.176332  [12800/30000]
# current batch loss: 0.185048  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.180708
# -----------------------------------------------
# avg val loss per batch: 0.178628
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 0.176743  [    0/30000]
# current batch loss: 0.169447  [12800/30000]
# current batch loss: 0.158477  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.181338
# -----------------------------------------------
# avg val loss per batch: 0.180614
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 0.178879  [    0/30000]
# current batch loss: 0.160461  [12800/30000]
# current batch loss: 0.146454  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.167250
# -----------------------------------------------
# avg val loss per batch: 0.168256
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 0.240200  [    0/30000]
# current batch loss: 0.175882  [12800/30000]
# current batch loss: 0.178575  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.168569
# -----------------------------------------------
# avg val loss per batch: 0.169847
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 0.164076  [    0/30000]
# current batch loss: 0.144828  [12800/30000]
# current batch loss: 0.192765  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.162124
# -----------------------------------------------
# avg val loss per batch: 0.162124
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 0.157751  [    0/30000]
# current batch loss: 0.196724  [12800/30000]
# current batch loss: 0.130087  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.164015
# -----------------------------------------------
# avg val loss per batch: 0.165088
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 0.162287  [    0/30000]
# current batch loss: 0.207584  [12800/30000]
# current batch loss: 0.152935  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.156061
# -----------------------------------------------
# avg val loss per batch: 0.157274
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 0.161205  [    0/30000]
# current batch loss: 0.207597  [12800/30000]
# current batch loss: 0.144690  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.150140
# -----------------------------------------------
# avg val loss per batch: 0.152104
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 0.131899  [    0/30000]
# current batch loss: 0.176619  [12800/30000]
# current batch loss: 0.161809  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.148120
# -----------------------------------------------
# avg val loss per batch: 0.150110
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 0.156663  [    0/30000]
# current batch loss: 0.120810  [12800/30000]
# current batch loss: 0.136311  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.152393
# -----------------------------------------------
# avg val loss per batch: 0.155139
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 0.170381  [    0/30000]
# current batch loss: 0.182136  [12800/30000]
# current batch loss: 0.147779  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.147909
# -----------------------------------------------
# avg val loss per batch: 0.149214
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 0.179363  [    0/30000]
# current batch loss: 0.123730  [12800/30000]
# current batch loss: 0.146086  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.164133
# -----------------------------------------------
# avg val loss per batch: 0.165591
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 0.158427  [    0/30000]
# current batch loss: 0.125172  [12800/30000]
# current batch loss: 0.120237  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.137105
# -----------------------------------------------
# avg val loss per batch: 0.139476
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 0.138196  [    0/30000]
# current batch loss: 0.139933  [12800/30000]
# current batch loss: 0.198056  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.137808
# -----------------------------------------------
# avg val loss per batch: 0.140050
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 0.161465  [    0/30000]
# current batch loss: 0.104015  [12800/30000]
# current batch loss: 0.136910  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.137679
# -----------------------------------------------
# avg val loss per batch: 0.142764
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 0.115971  [    0/30000]
# current batch loss: 0.124875  [12800/30000]
# current batch loss: 0.134604  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.150475
# -----------------------------------------------
# avg val loss per batch: 0.156112
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 0.127326  [    0/30000]
# current batch loss: 0.150304  [12800/30000]
# current batch loss: 0.145593  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.134019
# -----------------------------------------------
# avg val loss per batch: 0.136697
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 0.097598  [    0/30000]
# current batch loss: 0.133473  [12800/30000]
# current batch loss: 0.129012  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.132194
# -----------------------------------------------
# avg val loss per batch: 0.135118
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 0.116918  [    0/30000]
# current batch loss: 0.096782  [12800/30000]
# current batch loss: 0.116586  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.167839
# -----------------------------------------------
# avg val loss per batch: 0.173498
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 0.201260  [    0/30000]
# current batch loss: 0.115949  [12800/30000]
# current batch loss: 0.118436  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.122177
# -----------------------------------------------
# avg val loss per batch: 0.125140
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 0.133996  [    0/30000]
# current batch loss: 0.096245  [12800/30000]
# current batch loss: 0.121328  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.132540
# -----------------------------------------------
# avg val loss per batch: 0.134501
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 0.148424  [    0/30000]
# current batch loss: 0.224372  [12800/30000]
# current batch loss: 0.148172  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.120518
# -----------------------------------------------
# avg val loss per batch: 0.123359
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 0.140165  [    0/30000]
# current batch loss: 0.095734  [12800/30000]
# current batch loss: 0.099106  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.122863
# -----------------------------------------------
# avg val loss per batch: 0.126749
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 0.126616  [    0/30000]
# current batch loss: 0.110473  [12800/30000]
# current batch loss: 0.097631  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.126016
# -----------------------------------------------
# avg val loss per batch: 0.130938
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 0.079097  [    0/30000]
# current batch loss: 0.115385  [12800/30000]
# current batch loss: 0.138556  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.124677
# -----------------------------------------------
# avg val loss per batch: 0.128556
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 0.123793  [    0/30000]
# current batch loss: 0.096053  [12800/30000]
# current batch loss: 0.192243  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.119462
# -----------------------------------------------
# avg val loss per batch: 0.122280
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 0.106879  [    0/30000]
# current batch loss: 0.112152  [12800/30000]
# current batch loss: 0.090428  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.128255
# -----------------------------------------------
# avg val loss per batch: 0.130963
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 0.114637  [    0/30000]
# current batch loss: 0.112780  [12800/30000]
# current batch loss: 0.101601  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.114877
# -----------------------------------------------
# avg val loss per batch: 0.118933
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 0.153123  [    0/30000]
# current batch loss: 0.128957  [12800/30000]
# current batch loss: 0.148663  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.121061
# -----------------------------------------------
# avg val loss per batch: 0.123482
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 0.123489  [    0/30000]
# current batch loss: 0.153538  [12800/30000]
# current batch loss: 0.123687  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.111190
# -----------------------------------------------
# avg val loss per batch: 0.114782
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 0.118641  [    0/30000]
# current batch loss: 0.112182  [12800/30000]
# current batch loss: 0.106407  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.113063
# -----------------------------------------------
# avg val loss per batch: 0.116150
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 0.114887  [    0/30000]
# current batch loss: 0.115568  [12800/30000]
# current batch loss: 0.103544  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.110053
# -----------------------------------------------
# avg val loss per batch: 0.113263
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 0.119575  [    0/30000]
# current batch loss: 0.112431  [12800/30000]
# current batch loss: 0.156310  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.118496
# -----------------------------------------------
# avg val loss per batch: 0.120452
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 0.113689  [    0/30000]
# current batch loss: 0.105306  [12800/30000]
# current batch loss: 0.085158  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.109972
# -----------------------------------------------
# avg val loss per batch: 0.114707
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 0.149383  [    0/30000]
# current batch loss: 0.137525  [12800/30000]
# current batch loss: 0.131638  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.116816
# -----------------------------------------------
# avg val loss per batch: 0.121705
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 0.115938  [    0/30000]
# current batch loss: 0.079740  [12800/30000]
# current batch loss: 0.135298  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.103877
# -----------------------------------------------
# avg val loss per batch: 0.107880
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 0.088316  [    0/30000]
# current batch loss: 0.101170  [12800/30000]
# current batch loss: 0.124337  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.111278
# -----------------------------------------------
# avg val loss per batch: 0.113554
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 0.111384  [    0/30000]
# current batch loss: 0.096552  [12800/30000]
# current batch loss: 0.115140  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.151241
# -----------------------------------------------
# avg val loss per batch: 0.157483
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 0.196961  [    0/30000]
# current batch loss: 0.094048  [12800/30000]
# current batch loss: 0.084086  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.105204
# -----------------------------------------------
# avg val loss per batch: 0.108972
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 0.107359  [    0/30000]
# current batch loss: 0.083632  [12800/30000]
# current batch loss: 0.103897  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.104697
# -----------------------------------------------
# avg val loss per batch: 0.108579
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 0.084115  [    0/30000]
# current batch loss: 0.070704  [12800/30000]
# current batch loss: 0.086579  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.101857
# -----------------------------------------------
# avg val loss per batch: 0.104925
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 0.082094  [    0/30000]
# current batch loss: 0.109915  [12800/30000]
# current batch loss: 0.089504  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.123858
# -----------------------------------------------
# avg val loss per batch: 0.127921
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 0.131188  [    0/30000]
# current batch loss: 0.103722  [12800/30000]
# current batch loss: 0.092281  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.101475
# -----------------------------------------------
# avg val loss per batch: 0.105497
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 0.093665  [    0/30000]
# current batch loss: 0.152631  [12800/30000]
# current batch loss: 0.114372  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.103766
# -----------------------------------------------
# avg val loss per batch: 0.105849
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 0.127249  [    0/30000]
# current batch loss: 0.099295  [12800/30000]
# current batch loss: 0.081669  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.099047
# -----------------------------------------------
# avg val loss per batch: 0.103203
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 0.104944  [    0/30000]
# current batch loss: 0.081364  [12800/30000]
# current batch loss: 0.101321  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.096973
# -----------------------------------------------
# avg val loss per batch: 0.099991
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 0.088687  [    0/30000]
# current batch loss: 0.082849  [12800/30000]
# current batch loss: 0.097998  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.092871
# -----------------------------------------------
# avg val loss per batch: 0.096652
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 0.073054  [    0/30000]
# current batch loss: 0.090740  [12800/30000]
# current batch loss: 0.120255  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.093352
# -----------------------------------------------
# avg val loss per batch: 0.097113
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 0.115400  [    0/30000]
# current batch loss: 0.092299  [12800/30000]
# current batch loss: 0.088491  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.111882
# -----------------------------------------------
# avg val loss per batch: 0.113422
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 0.133384  [    0/30000]
# current batch loss: 0.080323  [12800/30000]
# current batch loss: 0.100159  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.091776
# -----------------------------------------------
# avg val loss per batch: 0.095157
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 0.087463  [    0/30000]
# current batch loss: 0.107643  [12800/30000]
# current batch loss: 0.111128  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.097807
# -----------------------------------------------
# avg val loss per batch: 0.100328
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 0.099733  [    0/30000]
# current batch loss: 0.059348  [12800/30000]
# current batch loss: 0.091717  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.088689
# -----------------------------------------------
# avg val loss per batch: 0.091288
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 0.077590  [    0/30000]
# current batch loss: 0.081731  [12800/30000]
# current batch loss: 0.092791  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.095188
# -----------------------------------------------
# avg val loss per batch: 0.098271
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 0.102256  [    0/30000]
# current batch loss: 0.088289  [12800/30000]
# current batch loss: 0.110616  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.086009
# -----------------------------------------------
# avg val loss per batch: 0.088250
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 0.114862  [    0/30000]
# current batch loss: 0.107358  [12800/30000]
# current batch loss: 0.090886  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.093827
# -----------------------------------------------
# avg val loss per batch: 0.097599
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 0.093349  [    0/30000]
# current batch loss: 0.085496  [12800/30000]
# current batch loss: 0.062789  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.090701
# -----------------------------------------------
# avg val loss per batch: 0.094451
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 0.110392  [    0/30000]
# current batch loss: 0.068887  [12800/30000]
# current batch loss: 0.106863  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.086750
# -----------------------------------------------
# avg val loss per batch: 0.090270
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 0.078657  [    0/30000]
# current batch loss: 0.092776  [12800/30000]
# current batch loss: 0.071095  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.103723
# -----------------------------------------------
# avg val loss per batch: 0.107513
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 0.106388  [    0/30000]
# current batch loss: 0.076873  [12800/30000]
# current batch loss: 0.097035  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.087239
# -----------------------------------------------
# avg val loss per batch: 0.089065
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 0.088607  [    0/30000]
# current batch loss: 0.077582  [12800/30000]
# current batch loss: 0.105434  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.083484
# -----------------------------------------------
# avg val loss per batch: 0.085859
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 0.077734  [    0/30000]
# current batch loss: 0.124251  [12800/30000]
# current batch loss: 0.101304  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.084438
# -----------------------------------------------
# avg val loss per batch: 0.087753
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 0.079721  [    0/30000]
# current batch loss: 0.060521  [12800/30000]
# current batch loss: 0.069425  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.089080
# -----------------------------------------------
# avg val loss per batch: 0.090686
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 0.088497  [    0/30000]
# current batch loss: 0.075929  [12800/30000]
# current batch loss: 0.113619  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.084375
# -----------------------------------------------
# avg val loss per batch: 0.086114
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 0.107326  [    0/30000]
# current batch loss: 0.066687  [12800/30000]
# current batch loss: 0.068099  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.085454
# -----------------------------------------------
# avg val loss per batch: 0.087279
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 0.085182  [    0/30000]
# current batch loss: 0.105002  [12800/30000]
# current batch loss: 0.101717  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.078018
# -----------------------------------------------
# avg val loss per batch: 0.080755
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 0.091232  [    0/30000]
# current batch loss: 0.084653  [12800/30000]
# current batch loss: 0.084848  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.101428
# -----------------------------------------------
# avg val loss per batch: 0.105852
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 0.133628  [    0/30000]
# current batch loss: 0.048321  [12800/30000]
# current batch loss: 0.070581  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.087100
# -----------------------------------------------
# avg val loss per batch: 0.090488
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 0.092381  [    0/30000]
# current batch loss: 0.065634  [12800/30000]
# current batch loss: 0.089353  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.082433
# -----------------------------------------------
# avg val loss per batch: 0.085102
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 0.063941  [    0/30000]
# current batch loss: 0.099289  [12800/30000]
# current batch loss: 0.091613  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.081636
# -----------------------------------------------
# avg val loss per batch: 0.083349
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 0.098004  [    0/30000]
# current batch loss: 0.080547  [12800/30000]
# current batch loss: 0.063017  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.091304
# -----------------------------------------------
# avg val loss per batch: 0.096019
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 0.080237  [    0/30000]
# current batch loss: 0.075963  [12800/30000]
# current batch loss: 0.086712  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.077893
# -----------------------------------------------
# avg val loss per batch: 0.080054
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 0.076324  [    0/30000]
# current batch loss: 0.054769  [12800/30000]
# current batch loss: 0.078623  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.098771
# -----------------------------------------------
# avg val loss per batch: 0.101004
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 0.091611  [    0/30000]
# current batch loss: 0.091279  [12800/30000]
# current batch loss: 0.071106  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.075707
# -----------------------------------------------
# avg val loss per batch: 0.078546
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 0.061399  [    0/30000]
# current batch loss: 0.063551  [12800/30000]
# current batch loss: 0.046589  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.077280
# -----------------------------------------------
# avg val loss per batch: 0.080506
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 0.117467  [    0/30000]
# current batch loss: 0.080087  [12800/30000]
# current batch loss: 0.069666  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.076453
# -----------------------------------------------
# avg val loss per batch: 0.079280
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 0.091418  [    0/30000]
# current batch loss: 0.088518  [12800/30000]
# current batch loss: 0.062375  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.075363
# -----------------------------------------------
# avg val loss per batch: 0.077697
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 0.111395  [    0/30000]
# current batch loss: 0.070665  [12800/30000]
# current batch loss: 0.073604  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.079198
# -----------------------------------------------
# avg val loss per batch: 0.081551
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 0.078111  [    0/30000]
# current batch loss: 0.068266  [12800/30000]
# current batch loss: 0.073284  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.079682
# -----------------------------------------------
# avg val loss per batch: 0.080172
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 0.097091  [    0/30000]
# current batch loss: 0.095223  [12800/30000]
# current batch loss: 0.072928  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.079268
# -----------------------------------------------
# avg val loss per batch: 0.080787
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 0.063518  [    0/30000]
# current batch loss: 0.048365  [12800/30000]
# current batch loss: 0.068610  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.085746
# -----------------------------------------------
# avg val loss per batch: 0.089169
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 0.087574  [    0/30000]
# current batch loss: 0.073714  [12800/30000]
# current batch loss: 0.054329  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.072613
# -----------------------------------------------
# avg val loss per batch: 0.075425
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 0.063317  [    0/30000]
# current batch loss: 0.069268  [12800/30000]
# current batch loss: 0.069049  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.070667
# -----------------------------------------------
# avg val loss per batch: 0.073088
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 0.064132  [    0/30000]
# current batch loss: 0.080311  [12800/30000]
# current batch loss: 0.079699  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.074154
# -----------------------------------------------
# avg val loss per batch: 0.076614
# -----------------------------------------------
# |
# ...
# -----------------------------------------------
# avg trn loss per batch: 0.071262
# -----------------------------------------------
# avg val loss per batch: 0.073215
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 0.077507  [    0/30000]
# current batch loss: 0.073790  [12800/30000]
# current batch loss: 0.090605  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.066975
# -----------------------------------------------
# avg val loss per batch: 0.069328
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 0.058063  [    0/30000]
# current batch loss: 0.070883  [12800/30000]
# current batch loss: 0.078850  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.080274
# -----------------------------------------------
# avg val loss per batch: 0.082866
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 0.076622  [    0/30000]
# current batch loss: 0.077360  [12800/30000]
# current batch loss: 0.053604  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.076939
# -----------------------------------------------
# avg val loss per batch: 0.079454
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 0.068528  [    0/30000]
# current batch loss: 0.072252  [12800/30000]
# current batch loss: 0.097952  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.083196
# -----------------------------------------------
# avg val loss per batch: 0.087224
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 0.078581  [    0/30000]
# current batch loss: 0.068485  [12800/30000]
# current batch loss: 0.070175  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.069117
# -----------------------------------------------
# avg val loss per batch: 0.071559
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 0.060186  [    0/30000]
# current batch loss: 0.081424  [12800/30000]
# current batch loss: 0.055369  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.072791
# -----------------------------------------------
# avg val loss per batch: 0.075569
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 0.064645  [    0/30000]
# current batch loss: 0.053001  [12800/30000]
# current batch loss: 0.033874  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.071236
# -----------------------------------------------
# avg val loss per batch: 0.073254
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 0.083220  [    0/30000]
# current batch loss: 0.081102  [12800/30000]
# current batch loss: 0.067769  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.067235
# -----------------------------------------------
# avg val loss per batch: 0.070828
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 0.079748  [    0/30000]
# current batch loss: 0.075732  [12800/30000]
# current batch loss: 0.063444  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.064112
# -----------------------------------------------
# avg val loss per batch: 0.066353
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 0.045357  [    0/30000]
# current batch loss: 0.056990  [12800/30000]
# current batch loss: 0.081852  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.065531
# -----------------------------------------------
# avg val loss per batch: 0.067658
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 0.044767  [    0/30000]
# current batch loss: 0.057389  [12800/30000]
# current batch loss: 0.057203  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.069318
# -----------------------------------------------
# avg val loss per batch: 0.073007
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 0.052210  [    0/30000]
# current batch loss: 0.096978  [12800/30000]
# current batch loss: 0.042439  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.060440
# -----------------------------------------------
# avg val loss per batch: 0.063079
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 0.059677  [    0/30000]
# current batch loss: 0.064309  [12800/30000]
# current batch loss: 0.068110  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.076722
# -----------------------------------------------
# avg val loss per batch: 0.080290
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 0.067849  [    0/30000]
# current batch loss: 0.065639  [12800/30000]
# current batch loss: 0.053888  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.063030
# -----------------------------------------------
# avg val loss per batch: 0.066180
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 0.068640  [    0/30000]
# current batch loss: 0.092932  [12800/30000]
# current batch loss: 0.057783  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.061804
# -----------------------------------------------
# avg val loss per batch: 0.064696
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 131
# -----------------------------------------------
# current batch loss: 0.050902  [    0/30000]
# current batch loss: 0.079091  [12800/30000]
# current batch loss: 0.064020  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.058404
# -----------------------------------------------
# avg val loss per batch: 0.061864
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 132
# -----------------------------------------------
# current batch loss: 0.058695  [    0/30000]
# current batch loss: 0.073053  [12800/30000]
# current batch loss: 0.060651  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.068265
# -----------------------------------------------
# avg val loss per batch: 0.071189
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 133
# -----------------------------------------------
# current batch loss: 0.070770  [    0/30000]
# current batch loss: 0.054203  [12800/30000]
# current batch loss: 0.070094  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.058928
# -----------------------------------------------
# avg val loss per batch: 0.061730
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 134
# -----------------------------------------------
# current batch loss: 0.064236  [    0/30000]
# current batch loss: 0.051092  [12800/30000]
# current batch loss: 0.046436  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.063519
# -----------------------------------------------
# avg val loss per batch: 0.065964
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 135
# -----------------------------------------------
# current batch loss: 0.045855  [    0/30000]
# current batch loss: 0.051728  [12800/30000]
# current batch loss: 0.066115  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.064487
# -----------------------------------------------
# avg val loss per batch: 0.066602
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 136
# -----------------------------------------------
# current batch loss: 0.056692  [    0/30000]
# current batch loss: 0.089988  [12800/30000]
# current batch loss: 0.059378  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.057897
# -----------------------------------------------
# avg val loss per batch: 0.060658
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 137
# -----------------------------------------------
# current batch loss: 0.076163  [    0/30000]
# current batch loss: 0.051640  [12800/30000]
# current batch loss: 0.067536  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.054479
# -----------------------------------------------
# avg val loss per batch: 0.056849
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 138
# -----------------------------------------------
# current batch loss: 0.052175  [    0/30000]
# current batch loss: 0.060850  [12800/30000]
# current batch loss: 0.032046  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.054296
# -----------------------------------------------
# avg val loss per batch: 0.057200
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 139
# -----------------------------------------------
# current batch loss: 0.045535  [    0/30000]
# current batch loss: 0.054720  [12800/30000]
# current batch loss: 0.080156  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.055481
# -----------------------------------------------
# avg val loss per batch: 0.057451
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 140
# -----------------------------------------------
# current batch loss: 0.061768  [    0/30000]
# current batch loss: 0.046834  [12800/30000]
# current batch loss: 0.074702  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.065085
# -----------------------------------------------
# avg val loss per batch: 0.068051
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 141
# -----------------------------------------------
# current batch loss: 0.053847  [    0/30000]
# current batch loss: 0.059551  [12800/30000]
# current batch loss: 0.049968  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.055123
# -----------------------------------------------
# avg val loss per batch: 0.058070
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 142
# -----------------------------------------------
# current batch loss: 0.072762  [    0/30000]
# current batch loss: 0.051189  [12800/30000]
# current batch loss: 0.054519  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.057701
# -----------------------------------------------
# avg val loss per batch: 0.059739
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 143
# -----------------------------------------------
# current batch loss: 0.049959  [    0/30000]
# current batch loss: 0.048146  [12800/30000]
# current batch loss: 0.066709  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.054793
# -----------------------------------------------
# avg val loss per batch: 0.057823
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 144
# -----------------------------------------------
# current batch loss: 0.045572  [    0/30000]
# current batch loss: 0.041813  [12800/30000]
# current batch loss: 0.057318  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.052529
# -----------------------------------------------
# avg val loss per batch: 0.054814
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 145
# -----------------------------------------------
# current batch loss: 0.066149  [    0/30000]
# current batch loss: 0.103104  [12800/30000]
# current batch loss: 0.053386  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.053378
# -----------------------------------------------
# avg val loss per batch: 0.055606
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 146
# -----------------------------------------------
# current batch loss: 0.042186  [    0/30000]
# current batch loss: 0.063531  [12800/30000]
# current batch loss: 0.073998  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.095138
# -----------------------------------------------
# avg val loss per batch: 0.098861
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 147
# -----------------------------------------------
# current batch loss: 0.092811  [    0/30000]
# current batch loss: 0.057588  [12800/30000]
# current batch loss: 0.076029  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.052962
# -----------------------------------------------
# avg val loss per batch: 0.055242
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 148
# -----------------------------------------------
# current batch loss: 0.048731  [    0/30000]
# current batch loss: 0.059099  [12800/30000]
# current batch loss: 0.036637  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.051747
# -----------------------------------------------
# avg val loss per batch: 0.054351
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 149
# -----------------------------------------------
# current batch loss: 0.061468  [    0/30000]
# current batch loss: 0.045744  [12800/30000]
# current batch loss: 0.062748  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.053780
# -----------------------------------------------
# avg val loss per batch: 0.056124
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 150
# -----------------------------------------------
# current batch loss: 0.048987  [    0/30000]
# current batch loss: 0.043605  [12800/30000]
# current batch loss: 0.040019  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.061261
# -----------------------------------------------
# avg val loss per batch: 0.064176
# -----------------------------------------------
# |
# Done!

# %% [markdown]
# ## Plot the train and validation losses as a function of the epochs

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses, label="train loss", color=c1 )
axs.plot( val_losses, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# We can see that both the train and validation losses are being reduced during training, the model is fitting well!
#
# We haven't used the test data here.  The test data becomes useful if our neural network overfits the training data, and we want to stop training the network early.  In this case we use the validation data to decide at which epoch to stop training, based on some early stopping condition.  For example, if the validation loss does not improve for 10 epochs, we might decide to stop training.  If we have saved the network at certain epochs during training, we would then select the network with the smallest validation loss to use.  The test data is then the final dataset we test on, since it was not used during training or in the early stopping procedure.

# %% [markdown]
# ## Study the results

# %% [markdown]
# Now we want to get some visualisation of how well our amplitude regression has worked.
#
# The simplest thing we can do is to pass our data through the neural network to get a predicted amplitude for each event, then histogram this and compare it to the histogram of the true amplitudes.

# %%
def get_amps( model, dataloader ):
    
    amps = []

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            amps += [ a.item() for a in model( X ) ]

    return amps

# %%
pred_trn_ampls = get_amps( model, trn_dataloader )
pred_val_ampls = get_amps( model, val_dataloader )

# %% [markdown]
# First for the training data:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

(n1, bins, patches1 ) = axs.hist( trn_ampl, histtype='stepfilled', fill=None, edgecolor=c1, label="train data", ls="--" )
(n2, bins, patches2 ) = axs.hist( pred_trn_ampls, histtype='stepfilled', fill=None, edgecolor=c2, label="train preds", bins=bins )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %%
matplotlib.rcParams["text.usetex"]  = True

# %% [markdown]
# We can also try to visualise the error on the predicted amplitudes by plotting $\text{abs}\left((A_{\text{true}}-A_{\text{pred}})/A_{\text{true}} \right)$.

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( np.abs((n1-n2)/n1), color=c1 )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "Error", fontproperties=axislabelfont )

xticks = np.round( axs.get_xticks(), 2 )
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = np.round( axs.get_yticks(), 2 )
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The error is lowest in the regions where there is more training data, this is expected.  The more data the network has to learn from, the better it can learn to predict the correct amplitude.

# %% [markdown]
# And then for the validation data:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

(n1, bins, patches1) = axs.hist( val_ampl, histtype='stepfilled', fill=None, edgecolor=c1, label="val data", ls="--" )
(n2, bins, patches2) = axs.hist( pred_val_ampls, histtype='stepfilled', fill=None, edgecolor=c2, label="val preds", bins=bins )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( np.abs((n1-n2)/n1), color=c1 )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "Error", fontproperties=axislabelfont )

xticks = np.round( axs.get_xticks(), 2 )
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = np.round( axs.get_yticks(), 2 )
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# ## Improvements?

# %% [markdown]
# General ways to improve ML analyses:
# - more data
# - larger network
# - longer training
# - better optimization

# %% [markdown]
# What about improvements that could be made specific to this physics example?

# %% [markdown]
# We could take advantage of the physical symmetries in the problem:
# - permutation invariance of:
#     - initial gluons
#     - outgoing photons
# - azimuthal symmetry of the amplitude due to alignment of initial gluons
