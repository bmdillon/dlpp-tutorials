# %% [markdown]
# # Network regularisation and preprocessing

# %% [markdown]
# In this tutorial we'll build directly on top of what we did in the amplitude regression task in the previous tutorial.  The first goal is to learn about the issue of over-training, and how to overcome it with network regularisation and early stopping. The second goal is to learn more about the different types of preprocessing that can be used in machine learning.

# %% [markdown]
# #### Outline / tasks:
#  - Imports \& plotting set-up
#  - Loading the data
#      - limit the training data to just 1000 events, keeping 30k for validation and testing
#      - this is unrealistic, but a good way to understand over-fitting and how to fix it
#  - Visualising the data
#  - Preprocessing the data
#  - Datasets and dataloaders
#      - choose a sensible batch size, say 64
#  - Building the neural network
#      - use a larger network, say 3 layers with hidden dimensions of 50
#  - Optimising (training) the neural network
#      - train for a long time, 1000-1500 epochs
#  - Plot the train and validation losses as a function of the epochs
#      - now you should clearly see the over-training problem
#  - Network regularisation
#      - Dropout
#          - implement a new network, amp_net_dr, which has a pytorch dropout layer after the input layer and each hidden layer
#          - re-train the network and check if dropout has fixed the over-fitting
#      - L1 / L2 regularisation
#      - Early stopping
#      - Batch normalisation
#  - Exploring preprocessing options
#      - check what happens if you don't preprocess your data at all..
#      - Look at the scikit-learn package a try out a few different data preprocessing functions, e.g. StandardScaler
#      - See how these affect the data visualisations
#      - Find preprocessing functions that are suitable for the 4-momentum inputs, and some that are suitable for the amplitudes

# %% [markdown]
# ### Imports

# %%
import os
import sys
import random
import time
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import nn

# %% [markdown]
# #### Plotting set-up

# %%
from matplotlib import pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
from matplotlib.lines import Line2D
from matplotlib.font_manager import FontProperties
import matplotlib.colors as mcolors
import colorsys

labelfont = FontProperties()
labelfont.set_family('serif')
labelfont.set_name('Times New Roman')
labelfont.set_size(14)

axislabelfont = FontProperties()
axislabelfont.set_family('serif')
axislabelfont.set_name('Times New Roman')
axislabelfont.set_size(22)

tickfont = FontProperties()
tickfont.set_family('serif')
tickfont.set_name('Times New Roman')
tickfont.set_size(16)

axisfontsize = 16
labelfontsize = 16

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams['text.usetex'] = True

# %% [markdown]
# ## Loading the data

# %%
trn_dat = np.load( "tutorial-2-data/trn_dat.npy" )
trn_amp = np.load( "tutorial-2-data/trn_amp.npy" )

val_dat = np.load( "tutorial-2-data/val_dat.npy" )
val_amp = np.load( "tutorial-2-data/val_amp.npy" )

tst_dat = np.load( "tutorial-2-data/tst_dat.npy" )
tst_amp = np.load( "tutorial-2-data/tst_amp.npy" )

# %%
print( f"train data shape: {trn_dat.shape}" )
print( f"train amp  shape: {trn_amp.shape}" )
print( f"test  data shape: {tst_dat.shape}" )
print( f"test  amp  shape: {tst_amp.shape}" )
print( f"val   data shape: {val_dat.shape}" )
print( f"val   amp  shape: {val_amp.shape}" )
# Out:
# train data shape: (30000, 5, 4)
# train amp  shape: (30000,)
# test  data shape: (30000, 5, 4)
# test  amp  shape: (30000,)
# val   data shape: (30000, 5, 4)
# val   amp  shape: (30000,)

# %% [markdown]
# Let's say we have much less data:

# %%
trn_dat = trn_dat[0:1000]
trn_amp = trn_amp[0:1000]
print( f"train data shape: {trn_dat.shape}" )
print( f"train amp  shape: {trn_amp.shape}" )
# Out:
# train data shape: (1000, 5, 4)
# train amp  shape: (1000,)

# %% [markdown]
# This is slightly unrealistic, but useful for demonstration purposes.  In practice we might use much larger networks than we use here, and so the number of parameters can be of the same order of magnitude as the number of training events.  This is when we encounter the problem of over-training.

# %% [markdown]
# ## Visualising the data

# %% [markdown]
# Below we will make some kinematic plots of the events in the training sample.  Note however that these are not the physical distributions we would measure at the LHC!  In our training data each of these events is associated with an amplitude, which tells us the probability that the event will be produced in the gluon-gluon interaction.  So to get the physical distributions these events would need to be 'weighted' by their amplitude.  However, right now we just want to visualise our training dataset to see what preprocessing we should do.

# %%
def get_init_pz( ev ):
    return ev[0][3] + ev[1][3]

def get_mass( fv ):
    msq = np.round( fv[0]**2 - fv[1]**2 - fv[2]**2 - fv[3]**2 , 5 )
    if msq>0:
        return np.sqrt( msq )
    elif msq<0:
        raise Exception( "mass squared is less than zero" ) 
    else:
        return 0
    
def get_pt( fv ):
    ptsq = np.round( fv[1]**2 + fv[2]**2 , 5 )
    if ptsq>0:
        return np.sqrt( ptsq )
    elif ptsq<0:
        raise Exception( "$p_T$ squared is less than zero" ) 
    else:
        return 0
    
def get_met( ev ):
    return np.abs( np.sum( [ fv[1]+fv[2] for fv in ev ] ) )

# %% [markdown]
# We can plot a histogram of the amplitudes for the training data.

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_amp, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )
axs.set_xscale( 'log' )

axs.set_xlabel( "train amplitudes", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The amplitudes span about 4 orders of magnitude...

# %% [markdown]
# Plotting the leading photon $p_T$.

# %%
trn_dat_leading_photon_pt = []
for ev in trn_dat:
    trn_dat_leading_photon_pt.append( get_pt( ev[2] ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_leading_photon_pt, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "leading photon $p_T$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# Plot the final state gluon $p_T$.

# %%
trn_dat_gluon_pt = []
for ev in trn_dat:
    trn_dat_gluon_pt.append( get_pt( ev[4] ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_gluon_pt, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "leading gluon $p_T$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# ## Preprocessing the data

# %% [markdown]
# We will be using a dense network, so the data needs to be in vector format.  We will collapse the data for each event to a single vector of dimension $5\times4=20$.  The fact that the data is ordered here is important.  To predict the amplitude given the kinematics, the network needs to know which entries correspond to which particles in the process.

# %%
trn_nev = trn_dat.shape[0]
val_nev = val_dat.shape[0]
tst_nev = tst_dat.shape[0]
trn_datf = np.reshape( trn_dat, (trn_nev,-1) )
val_datf = np.reshape( val_dat, (val_nev,-1) )
tst_datf = np.reshape( tst_dat, (tst_nev,-1) )

# %% [markdown]
# Check the shape:

# %%
trn_datf.shape
# Out:
# (1000, 20)

# %% [markdown]
# There are further preprocessing steps we can take.  For example, the inputs are numerically very large $\mathcal{O}(100)$ and span a large range.  So we could re-scale the inputs by a constant number, or even take the logarithm of the inputs.
#
# For now, we'll just re-scale by a constant number, the average final state gluon $p_T$, assuming that this is a natural scale for the problem.  And we should be careful to preprocess the train, validation, and test data in the exact same way.

# %%
trn_dat_gluon_pt = []
for ev in trn_dat:
    trn_dat_gluon_pt.append( get_pt( ev[4] ) )

# %%
gpt = np.mean( trn_dat_gluon_pt )
trn_datf = trn_datf / gpt
val_datf = val_datf / gpt
tst_datf = tst_datf / gpt

# %% [markdown]
# Now convert them to pytorch tensors.

# %%
trn_datfp = torch.Tensor( trn_datf )
val_datfp = torch.Tensor( val_datf )
tst_datfp = torch.Tensor( tst_datf )

# %% [markdown]
# We should also preprocess the amplitude data.  As we seen in a plot above, the amplitudes span about 4 orders of magnitude.  This could be difficult for the network to interpolate.  We can aleviate the problem with preprocessing, taking the logarithm of the amplitudes.

# %%
trn_ampl = np.log( trn_amp )
val_ampl = np.log( val_amp )
tst_ampl = np.log( tst_amp )

# %%
trn_amplp = torch.Tensor( trn_ampl )
val_amplp = torch.Tensor( val_ampl )
tst_amplp = torch.Tensor( tst_ampl )

# %% [markdown]
# The new distribution looks nicer:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_ampl, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# ## Datasets and dataloaders

# %% [markdown]
# First define a class for the datasets.

# %%
class amp_dataset( Dataset ):
    
    def __init__( self, data, amp ):
        self.data = data
        self.amp = amp

    def __len__(self):
        return len(self.amp)

    def __getitem__(self, idx):
        return self.data[idx], self.amp[idx]

# %% [markdown]
# Then initialise them with the data and amplitudes.  We use unsqueeze here so that the shape of the amplitudes matches the shape output from the neural network.

# %%
trn_dataset = amp_dataset( trn_datfp, trn_amplp.unsqueeze(-1) )
val_dataset = amp_dataset( val_datfp, val_amplp.unsqueeze(-1) )
tst_dataset = amp_dataset( tst_datfp, tst_amplp.unsqueeze(-1) )

# %% [markdown]
# Now we can define a dataloader for each of these datasets.

# %%
trn_dataloader = DataLoader( trn_dataset, batch_size=64, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=64, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=64, shuffle=True )

# %% [markdown]
# And we can check that the shape for the kinematic data and amplitudes come out correct.

# %% [markdown]
# ## Building the neural network

# %% [markdown]
# Now we build a very simple class for our neural network, which we call amp_net.

# %%
class amp_net( nn.Module ):
    
    # default hdn_dim is 30, but can be changed upon initialisation
    def __init__( self, hdn_dim=30 ):
        
        super( amp_net, self ).__init__()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear( ipt_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, opt_dim ),
        )

    def forward( self, x ):
        out = self.linear_relu_stack( x )
        return out

# %% [markdown]
# Check if we have a GPU.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# ## Optimising (training) the neural network

# %% [markdown]
# We need to decide what function we want the neural network to optimise, i.e. the loss function.  There are a number of choices to decide from, the key point is that the loss function should be minimised when the neural network correctly predicts the amplitude given the kinematical information on the event.  For this we'll use the MSE, the mean squared error.
#
# $\text{MSE} = ( \text{pred_amp} - \text{true_amp} )^2 $

# %%
loss_fn = nn.MSELoss()

# %% [markdown]
# PyTorch will compute gradients of this loss function with respect to the trainable parameters of the network.  The network is optimised by updating the parameters using the gradients.  The exact scheme to do this is defined by our choice of optimiser.  A standard choice is the Adam optimiser, which we will use here with it's default hyper-parameters.
#
# You can read more about this optimiser here:
#  - https://pytorch.org/docs/stable/generated/torch.optim.Adam.html
#  - https://arxiv.org/abs/1412.6980

# %% [markdown]
# We've already set the batch size when defining the dataloaders.  Below we set the number of epochs, i.e. the number of times we will iterate through the training data to optimise the network.  This means that the total number of updates to the network parameters will be $\simeq\text{size of dataset}\times \text{epochs} / \text{batch size}$.

# %% [markdown]
# Now we can write a training loop for a single epoch.

# %%
def train_epoch( dataloader, model, loss_fn, optimizer ):
    
    size = len( dataloader.dataset )
    
    for batch, (X, y) in enumerate(dataloader):

        # pass data through network
        pred = model(X)
        
        # compute loss
        loss = loss_fn( pred, y )

        # reset gradients in optimizer
        optimizer.zero_grad()
        
        # compute gradients
        loss.backward()
        
        # update weights with optimizer
        optimizer.step()
        
        # print the training loss every 100 updates
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print( f"current batch loss: {loss:>7f}  [{current:>5d}/{size:>5d}]" )

# %% [markdown]
# To monitor the performance of the network on the regression task we want to calculate the loss of both the training data and the validation data on the same network, so we have the following functions:

# %%
def val_pass( dataloader, model, loss_fn ):
    
    size = len( dataloader.dataset )
    num_batches = len( dataloader )
    vl = 0.0

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            pred = model( X )
            vl += loss_fn( pred, y ).item()

    vl /= num_batches
    print( f"avg val loss per batch: {vl:>8f}" )
    
    return vl

def trn_pass( dataloader, model, loss_fn ):
    
    size = len( dataloader.dataset )
    num_batches = len( dataloader )
    tl = 0.0

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            pred = model( X )
            tl += loss_fn( pred, y ).item()

    tl /= num_batches
    print( f"avg trn loss per batch: {tl:>8f}" )
    
    return tl

# %% [markdown]
# Now we can train the model!

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# define parameters
ipt_dim = 20
opt_dim = 1
hdn_dim = 50
batch_size = 64
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 1500

# re-initialise the model and the optimizer
hdn_dim = 50
model = amp_net( hdn_dim=hdn_dim ).to(device)
learning_rate = 5e-4
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate )
seperator()
print( "model architecture ")
seperator()
print( model )

# track train and val losses
trn_losses = []
val_losses = []

for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model, loss_fn, optimizer )
    seperator()
    trn_loss = trn_pass( trn_dataloader, model, loss_fn )
    trn_losses.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model, loss_fn )
    val_losses.append( val_loss )
    seperator()
    print( "|" )
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=50, out_features=50, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 215.065033  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 208.479194
# -----------------------------------------------
# avg val loss per batch: 210.141555
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 205.545990  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 191.557706
# -----------------------------------------------
# avg val loss per batch: 192.914437
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 190.731964  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 144.869284
# -----------------------------------------------
# avg val loss per batch: 144.873143
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 143.079849  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 56.839134
# -----------------------------------------------
# avg val loss per batch: 56.423494
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 60.993172  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 40.272187
# -----------------------------------------------
# avg val loss per batch: 45.442363
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 27.206205  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 32.884429
# -----------------------------------------------
# avg val loss per batch: 34.678961
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 33.949192  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 30.682429
# -----------------------------------------------
# avg val loss per batch: 32.941837
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 31.796925  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 28.932435
# -----------------------------------------------
# avg val loss per batch: 31.748176
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 30.727331  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 27.475349
# -----------------------------------------------
# avg val loss per batch: 29.851375
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 20.290073  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 26.119491
# -----------------------------------------------
# avg val loss per batch: 28.635122
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 25.298439  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 24.798487
# -----------------------------------------------
# avg val loss per batch: 26.976346
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 27.713043  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 23.166410
# -----------------------------------------------
# avg val loss per batch: 25.489430
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 33.565990  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 21.554066
# -----------------------------------------------
# avg val loss per batch: 23.879425
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 22.589746  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 19.648680
# -----------------------------------------------
# avg val loss per batch: 22.037733
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 19.519569  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 18.247302
# -----------------------------------------------
# avg val loss per batch: 20.252560
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 14.757924  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 16.458441
# -----------------------------------------------
# avg val loss per batch: 18.175157
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 17.903702  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 14.448641
# -----------------------------------------------
# avg val loss per batch: 16.349528
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 14.897928  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 12.302790
# -----------------------------------------------
# avg val loss per batch: 13.948506
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 13.655910  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 10.532591
# -----------------------------------------------
# avg val loss per batch: 11.725825
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 9.302350  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 8.379033
# -----------------------------------------------
# avg val loss per batch: 9.852457
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 14.800755  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 6.285531
# -----------------------------------------------
# avg val loss per batch: 7.476592
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 8.387980  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 4.663149
# -----------------------------------------------
# avg val loss per batch: 5.572081
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 4.134043  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.339883
# -----------------------------------------------
# avg val loss per batch: 4.126253
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 3.468022  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.414808
# -----------------------------------------------
# avg val loss per batch: 3.050161
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 3.157486  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.876396
# -----------------------------------------------
# avg val loss per batch: 2.274867
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 1.181634  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.472286
# -----------------------------------------------
# avg val loss per batch: 1.782785
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 1.442601  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.276712
# -----------------------------------------------
# avg val loss per batch: 1.519251
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 1.433861  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.015818
# -----------------------------------------------
# avg val loss per batch: 1.264982
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 2.078060  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.897651
# -----------------------------------------------
# avg val loss per batch: 1.101837
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 0.784742  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.823145
# -----------------------------------------------
# avg val loss per batch: 1.015860
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 1.349478  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.729281
# -----------------------------------------------
# avg val loss per batch: 0.930545
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 0.634413  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.728394
# -----------------------------------------------
# avg val loss per batch: 0.932391
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 0.434230  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.629061
# -----------------------------------------------
# avg val loss per batch: 0.816959
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 0.633983  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.599405
# -----------------------------------------------
# avg val loss per batch: 0.761600
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 0.625021  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.568421
# -----------------------------------------------
# avg val loss per batch: 0.717694
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 0.561738  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.565433
# -----------------------------------------------
# avg val loss per batch: 0.699785
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 0.579071  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.520258
# -----------------------------------------------
# avg val loss per batch: 0.667840
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 0.439593  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.508627
# -----------------------------------------------
# avg val loss per batch: 0.638894
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 0.474676  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.502446
# -----------------------------------------------
# avg val loss per batch: 0.620663
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 0.294467  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.505802
# -----------------------------------------------
# avg val loss per batch: 0.619809
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 0.624808  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.510507
# -----------------------------------------------
# avg val loss per batch: 0.656594
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 0.754536  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.457027
# -----------------------------------------------
# avg val loss per batch: 0.585925
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 0.457045  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.454598
# -----------------------------------------------
# avg val loss per batch: 0.569491
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 0.361976  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.444343
# -----------------------------------------------
# avg val loss per batch: 0.567870
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 0.477535  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.428602
# -----------------------------------------------
# avg val loss per batch: 0.546458
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 0.505102  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.418395
# -----------------------------------------------
# avg val loss per batch: 0.530102
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 0.282940  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.421608
# -----------------------------------------------
# avg val loss per batch: 0.541541
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 0.537225  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.430029
# -----------------------------------------------
# avg val loss per batch: 0.527007
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 0.365378  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.407663
# -----------------------------------------------
# avg val loss per batch: 0.510832
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 0.374908  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.396664
# -----------------------------------------------
# avg val loss per batch: 0.506574
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 0.435746  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.401988
# -----------------------------------------------
# avg val loss per batch: 0.501562
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 0.421639  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.390616
# -----------------------------------------------
# avg val loss per batch: 0.490804
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 0.505824  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.406843
# -----------------------------------------------
# avg val loss per batch: 0.534426
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 0.337732  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.373077
# -----------------------------------------------
# avg val loss per batch: 0.484391
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 0.301295  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.371311
# -----------------------------------------------
# avg val loss per batch: 0.472942
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 0.379168  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.371422
# -----------------------------------------------
# avg val loss per batch: 0.488021
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 0.450399  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.357432
# -----------------------------------------------
# avg val loss per batch: 0.459755
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 0.215810  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.359763
# -----------------------------------------------
# avg val loss per batch: 0.462327
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 0.410571  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.350839
# -----------------------------------------------
# avg val loss per batch: 0.462426
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 0.356575  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.351099
# -----------------------------------------------
# avg val loss per batch: 0.448929
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 0.404718  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.341119
# -----------------------------------------------
# avg val loss per batch: 0.457645
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 0.332961  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.337106
# -----------------------------------------------
# avg val loss per batch: 0.444441
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 0.314430  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.332888
# -----------------------------------------------
# avg val loss per batch: 0.438883
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 0.244145  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.344427
# -----------------------------------------------
# avg val loss per batch: 0.437970
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 0.386917  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.333331
# -----------------------------------------------
# avg val loss per batch: 0.444744
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 0.329522  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.333795
# -----------------------------------------------
# avg val loss per batch: 0.441292
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 0.387977  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.317832
# -----------------------------------------------
# avg val loss per batch: 0.427207
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 0.302187  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.314804
# -----------------------------------------------
# avg val loss per batch: 0.416972
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 0.259174  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.330159
# -----------------------------------------------
# avg val loss per batch: 0.446275
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 0.274658  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.311034
# -----------------------------------------------
# avg val loss per batch: 0.410651
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 0.288394  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.302758
# -----------------------------------------------
# avg val loss per batch: 0.408718
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 0.358607  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.308570
# -----------------------------------------------
# avg val loss per batch: 0.409825
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 0.351969  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.295858
# -----------------------------------------------
# avg val loss per batch: 0.403223
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 0.227609  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.297493
# -----------------------------------------------
# avg val loss per batch: 0.397763
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 0.330818  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.315431
# -----------------------------------------------
# avg val loss per batch: 0.413075
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 0.373412  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.290333
# -----------------------------------------------
# avg val loss per batch: 0.402947
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 0.220622  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.300633
# -----------------------------------------------
# avg val loss per batch: 0.403847
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 0.311007  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.283685
# -----------------------------------------------
# avg val loss per batch: 0.386462
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 0.228482  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.299294
# -----------------------------------------------
# avg val loss per batch: 0.422780
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 0.442316  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.273431
# -----------------------------------------------
# avg val loss per batch: 0.381903
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 0.212209  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.289563
# -----------------------------------------------
# avg val loss per batch: 0.382216
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 0.354427  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.297834
# -----------------------------------------------
# avg val loss per batch: 0.429585
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 0.228924  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.268189
# -----------------------------------------------
# avg val loss per batch: 0.377785
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 0.331986  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.272367
# -----------------------------------------------
# avg val loss per batch: 0.394837
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 0.270696  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.256669
# -----------------------------------------------
# avg val loss per batch: 0.373263
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 0.419339  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.253737
# -----------------------------------------------
# avg val loss per batch: 0.366162
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 0.263912  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.260353
# -----------------------------------------------
# avg val loss per batch: 0.379097
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 0.249410  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.247819
# -----------------------------------------------
# avg val loss per batch: 0.362540
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 0.224435  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.247518
# -----------------------------------------------
# avg val loss per batch: 0.366019
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 0.179718  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.241489
# -----------------------------------------------
# avg val loss per batch: 0.360320
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 0.274003  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.236408
# -----------------------------------------------
# avg val loss per batch: 0.352059
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 0.176816  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.252500
# -----------------------------------------------
# avg val loss per batch: 0.359603
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 0.325220  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.235016
# -----------------------------------------------
# avg val loss per batch: 0.349401
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 0.248692  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.230203
# -----------------------------------------------
# avg val loss per batch: 0.354423
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 0.223167  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.273120
# -----------------------------------------------
# avg val loss per batch: 0.377327
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 0.284400  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.224555
# -----------------------------------------------
# avg val loss per batch: 0.347414
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 0.226938  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.225224
# -----------------------------------------------
# avg val loss per batch: 0.341754
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 0.281686  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.220514
# -----------------------------------------------
# avg val loss per batch: 0.340864
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 0.219403  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.221344
# -----------------------------------------------
# avg val loss per batch: 0.343390
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 0.232056  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.216712
# -----------------------------------------------
# avg val loss per batch: 0.334874
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 0.175761  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.216333
# -----------------------------------------------
# avg val loss per batch: 0.330078
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 0.180461  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.215794
# -----------------------------------------------
# avg val loss per batch: 0.334708
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 0.206565  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.216554
# -----------------------------------------------
# avg val loss per batch: 0.330198
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 0.174973  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.213533
# -----------------------------------------------
# avg val loss per batch: 0.335016
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 0.239632  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.206322
# -----------------------------------------------
# avg val loss per batch: 0.329693
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 0.205677  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.211516
# -----------------------------------------------
# avg val loss per batch: 0.324939
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 107
# -----------------------------------------------
# current batch loss: 0.237919  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.202254
# -----------------------------------------------
# avg val loss per batch: 0.332505
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 108
# -----------------------------------------------
# current batch loss: 0.222780  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.202091
# -----------------------------------------------
# avg val loss per batch: 0.333155
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 109
# -----------------------------------------------
# current batch loss: 0.207872  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.221239
# -----------------------------------------------
# avg val loss per batch: 0.361427
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 110
# -----------------------------------------------
# current batch loss: 0.193329  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.194098
# -----------------------------------------------
# avg val loss per batch: 0.313562
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 111
# -----------------------------------------------
# current batch loss: 0.143917  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.196969
# -----------------------------------------------
# avg val loss per batch: 0.314235
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 112
# -----------------------------------------------
# current batch loss: 0.249578  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.199527
# -----------------------------------------------
# avg val loss per batch: 0.317379
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 113
# -----------------------------------------------
# current batch loss: 0.160490  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.190482
# -----------------------------------------------
# avg val loss per batch: 0.319891
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 114
# -----------------------------------------------
# current batch loss: 0.183870  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.194564
# -----------------------------------------------
# avg val loss per batch: 0.322050
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 115
# -----------------------------------------------
# current batch loss: 0.189506  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.188768
# -----------------------------------------------
# avg val loss per batch: 0.319342
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 0.183905  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.198959
# -----------------------------------------------
# avg val loss per batch: 0.312040
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 0.182217  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.186005
# -----------------------------------------------
# avg val loss per batch: 0.318974
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 0.119011  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.182709
# -----------------------------------------------
# avg val loss per batch: 0.306646
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 0.185624  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.202060
# -----------------------------------------------
# avg val loss per batch: 0.314702
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 0.200275  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.183615
# -----------------------------------------------
# avg val loss per batch: 0.304795
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 0.156826  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.176724
# -----------------------------------------------
# avg val loss per batch: 0.305545
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 0.156326  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.177419
# -----------------------------------------------
# avg val loss per batch: 0.301333
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 0.181713  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.191772
# -----------------------------------------------
# avg val loss per batch: 0.303862
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 0.246054  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.175537
# -----------------------------------------------
# avg val loss per batch: 0.302509
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 0.178175  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.174061
# -----------------------------------------------
# avg val loss per batch: 0.297766
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 0.188798  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.172019
# -----------------------------------------------
# avg val loss per batch: 0.301005
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 0.129056  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.170846
# -----------------------------------------------
# avg val loss per batch: 0.295099
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 0.134232  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.197871
# -----------------------------------------------
# avg val loss per batch: 0.310271
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 0.159333  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.260504
# -----------------------------------------------
# avg val loss per batch: 0.370605
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 0.365570  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.191649
# -----------------------------------------------
# avg val loss per batch: 0.307611
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 131
# -----------------------------------------------
# current batch loss: 0.187505  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.172395
# -----------------------------------------------
# avg val loss per batch: 0.296439
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 132
# ...
# |
# -----------------------------------------------
# Epoch 1457
# -----------------------------------------------
# current batch loss: 0.027509  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.026379
# -----------------------------------------------
# avg val loss per batch: 0.202518
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1458
# -----------------------------------------------
# current batch loss: 0.031757  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.021374
# -----------------------------------------------
# avg val loss per batch: 0.192908
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1459
# -----------------------------------------------
# current batch loss: 0.016940  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.019032
# -----------------------------------------------
# avg val loss per batch: 0.196259
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1460
# -----------------------------------------------
# current batch loss: 0.012588  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.023841
# -----------------------------------------------
# avg val loss per batch: 0.208081
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1461
# -----------------------------------------------
# current batch loss: 0.014245  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.024172
# -----------------------------------------------
# avg val loss per batch: 0.193490
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1462
# -----------------------------------------------
# current batch loss: 0.027660  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.029960
# -----------------------------------------------
# avg val loss per batch: 0.223689
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1463
# -----------------------------------------------
# current batch loss: 0.016300  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.024032
# -----------------------------------------------
# avg val loss per batch: 0.211077
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1464
# -----------------------------------------------
# current batch loss: 0.036165  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.033502
# -----------------------------------------------
# avg val loss per batch: 0.209338
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1465
# -----------------------------------------------
# current batch loss: 0.037548  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.027398
# -----------------------------------------------
# avg val loss per batch: 0.219736
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1466
# -----------------------------------------------
# current batch loss: 0.023503  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.028060
# -----------------------------------------------
# avg val loss per batch: 0.226159
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1467
# -----------------------------------------------
# current batch loss: 0.021925  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.024679
# -----------------------------------------------
# avg val loss per batch: 0.203305
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1468
# -----------------------------------------------
# current batch loss: 0.032530  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.034328
# -----------------------------------------------
# avg val loss per batch: 0.229857
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1469
# -----------------------------------------------
# current batch loss: 0.031042  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.022472
# -----------------------------------------------
# avg val loss per batch: 0.209279
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1470
# -----------------------------------------------
# current batch loss: 0.026461  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.025590
# -----------------------------------------------
# avg val loss per batch: 0.208645
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1471
# -----------------------------------------------
# current batch loss: 0.023283  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.020720
# -----------------------------------------------
# avg val loss per batch: 0.200923
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1472
# -----------------------------------------------
# current batch loss: 0.025797  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.019888
# -----------------------------------------------
# avg val loss per batch: 0.196116
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1473
# -----------------------------------------------
# current batch loss: 0.012992  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.020649
# -----------------------------------------------
# avg val loss per batch: 0.203794
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1474
# -----------------------------------------------
# current batch loss: 0.028075  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.022960
# -----------------------------------------------
# avg val loss per batch: 0.194832
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1475
# -----------------------------------------------
# current batch loss: 0.021090  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.025250
# -----------------------------------------------
# avg val loss per batch: 0.195819
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1476
# -----------------------------------------------
# current batch loss: 0.021458  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.019552
# -----------------------------------------------
# avg val loss per batch: 0.198333
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1477
# -----------------------------------------------
# current batch loss: 0.017589  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.025486
# -----------------------------------------------
# avg val loss per batch: 0.219795
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1478
# -----------------------------------------------
# current batch loss: 0.037063  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.038088
# -----------------------------------------------
# avg val loss per batch: 0.206186
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1479
# -----------------------------------------------
# current batch loss: 0.032894  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.027888
# -----------------------------------------------
# avg val loss per batch: 0.194776
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1480
# -----------------------------------------------
# current batch loss: 0.029536  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.022026
# -----------------------------------------------
# avg val loss per batch: 0.208954
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1481
# -----------------------------------------------
# current batch loss: 0.023955  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.020501
# -----------------------------------------------
# avg val loss per batch: 0.191251
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1482
# -----------------------------------------------
# current batch loss: 0.022104  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.026029
# -----------------------------------------------
# avg val loss per batch: 0.195949
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1483
# -----------------------------------------------
# current batch loss: 0.034257  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.024765
# -----------------------------------------------
# avg val loss per batch: 0.202588
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1484
# -----------------------------------------------
# current batch loss: 0.030316  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.023161
# -----------------------------------------------
# avg val loss per batch: 0.193545
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1485
# -----------------------------------------------
# current batch loss: 0.035091  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.039536
# -----------------------------------------------
# avg val loss per batch: 0.200504
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1486
# -----------------------------------------------
# current batch loss: 0.036865  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.024049
# -----------------------------------------------
# avg val loss per batch: 0.195895
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1487
# -----------------------------------------------
# current batch loss: 0.027008  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.020372
# -----------------------------------------------
# avg val loss per batch: 0.196120
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1488
# -----------------------------------------------
# current batch loss: 0.018865  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.030781
# -----------------------------------------------
# avg val loss per batch: 0.223308
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1489
# -----------------------------------------------
# current batch loss: 0.032328  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.019326
# -----------------------------------------------
# avg val loss per batch: 0.194149
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1490
# -----------------------------------------------
# current batch loss: 0.022559  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.028878
# -----------------------------------------------
# avg val loss per batch: 0.196339
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1491
# -----------------------------------------------
# current batch loss: 0.022549  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.021379
# -----------------------------------------------
# avg val loss per batch: 0.195074
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1492
# -----------------------------------------------
# current batch loss: 0.021910  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.024038
# -----------------------------------------------
# avg val loss per batch: 0.195455
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1493
# -----------------------------------------------
# current batch loss: 0.022254  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.038269
# -----------------------------------------------
# avg val loss per batch: 0.203027
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1494
# -----------------------------------------------
# current batch loss: 0.048972  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.021744
# -----------------------------------------------
# avg val loss per batch: 0.195305
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1495
# -----------------------------------------------
# current batch loss: 0.021891  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.019761
# -----------------------------------------------
# avg val loss per batch: 0.190464
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1496
# -----------------------------------------------
# current batch loss: 0.015536  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.027753
# -----------------------------------------------
# avg val loss per batch: 0.214584
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1497
# -----------------------------------------------
# current batch loss: 0.033293  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.025876
# -----------------------------------------------
# avg val loss per batch: 0.213921
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1498
# -----------------------------------------------
# current batch loss: 0.022167  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.021723
# -----------------------------------------------
# avg val loss per batch: 0.210160
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1499
# -----------------------------------------------
# current batch loss: 0.025423  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.032993
# -----------------------------------------------
# avg val loss per batch: 0.194683
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1500
# -----------------------------------------------
# current batch loss: 0.032555  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.022770
# -----------------------------------------------
# avg val loss per batch: 0.190829
# -----------------------------------------------
# |
# Done!

# %% [markdown]
# ## Plot the train and validation losses as a function of the epochs

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses, label="train loss", color=c1 )
axs.plot( val_losses, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = [ int(x) for x in axs.get_xticks() ]
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# This is a good example of a network over-training.  At some point, the loss evaluated on the training data continues to improve, while the loss on the validation data converges to a lower limit.  In practice, it often happens that the validation loss actually gets worse when the network over-trains, so the problem can be worse than shown here.

# %% [markdown]
# ## Network regularisation

# %% [markdown]
# ### Dropout

# %% [markdown]
# Dropout is a mechanism to reduce over-fitting effects in neural network optimisation.  It was proposed in this paper (I think):
#
# ------------------
#
# **Improving neural networks by preventing co-adaptation of feature detectors**
#
# https://arxiv.org/abs/1207.0580
#
# When a large feedforward neural network is trained on a small training set, it typically performs poorly on held-out test data. This "overfitting" is greatly reduced by randomly omitting half of the feature detectors on each training case. This prevents complex co-adaptations in which a feature detector is only helpful in the context of several other specific feature detectors. Instead, each neuron learns to detect a feature that is generally helpful for producing the correct answer given the combinatorially large variety of internal contexts in which it must operate. Random "dropout" gives big improvements on many benchmark tasks and sets new records for speech and object recognition.
#
# ------------------

# %% [markdown]
# Dropout is implemented as a layer in pytorch.
#
# The description given in the pytorch documentation is:
#
# ------------------
#
# https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html
#
# During training, randomly zeroes some of the elements of the input tensor with probability $p$ using samples from a Bernoulli distribution. Each channel will be zeroed out independently on every forward call.
#
# This has proven to be an effective technique for regularization and preventing the co-adaptation of neurons as described in the paper Improving neural networks by preventing co-adaptation of feature detectors .
#
# Furthermore, the outputs are scaled by a factor of $\frac{1}{1-p}$ during training. This means that during evaluation the module simply computes an identity function.
#
# ------------------

# %% [markdown]
# So let's build the same model, but with dropout:

# %%
class amp_net_dr( nn.Module ):
    
    # default hdn_dim is 30, but can be changed upon initialisation
    def __init__( self, hdn_dim=30 ):
        
        super( amp_net_dr, self ).__init__()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear( ipt_dim, hdn_dim ),
            nn.Dropout( p=0.5 ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.Dropout( p=0.5 ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.Dropout( p=0.5 ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.Dropout( p=0.5 ),
            nn.ReLU(),
            nn.Linear( hdn_dim, opt_dim ),
        )

    def forward( self, x ):
        out = self.linear_relu_stack( x )
        return out

# %% [markdown]
# When re-training the model we need to be careful.  When we evaluate the network on data to monitor performance, we don't want dropout to affect the results.  To do this we need to temporarily switch the model from `train` mode to `eval` mode.

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# define parameters
ipt_dim = 20
opt_dim = 1
hdn_dim = 50
batch_size = 64
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 1500

# re-initialise the model and the optimizer
hdn_dim = 50
model_dr = amp_net_dr( hdn_dim=hdn_dim ).to(device)
learning_rate = 5e-4
optimizer = torch.optim.Adam( model_dr.parameters(), lr=learning_rate )
seperator()
print( "model architecture ")
seperator()
print( model_dr )

# track train and val losses
trn_losses_dr = []
val_losses_dr = []

for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model_dr, loss_fn, optimizer )
    seperator()
    model_dr.eval()
    trn_loss = trn_pass( trn_dataloader, model_dr, loss_fn )
    trn_losses_dr.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model_dr, loss_fn )
    val_losses_dr.append( val_loss )
    model_dr.train()
    seperator()
    print( "|" )
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net_dr(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#     (3): Linear(in_features=50, out_features=50, bias=True)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): ReLU()
#     (6): Linear(in_features=50, out_features=50, bias=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): ReLU()
#     (9): Linear(in_features=50, out_features=50, bias=True)
#     (10): Dropout(p=0.5, inplace=False)
#     (11): ReLU()
#     (12): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 210.836075  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 204.863197
# -----------------------------------------------
# avg val loss per batch: 206.686013
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 195.592224  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 182.175167
# -----------------------------------------------
# avg val loss per batch: 183.350304
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 173.345383  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 117.257231
# -----------------------------------------------
# avg val loss per batch: 117.065414
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 109.048691  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 39.656538
# -----------------------------------------------
# avg val loss per batch: 40.705107
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 83.869797  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 41.500353
# -----------------------------------------------
# avg val loss per batch: 41.926548
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 46.703217  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 38.575149
# -----------------------------------------------
# avg val loss per batch: 39.368039
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 56.829697  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 34.265060
# -----------------------------------------------
# avg val loss per batch: 35.200941
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 41.545181  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 33.795296
# -----------------------------------------------
# avg val loss per batch: 34.561172
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 54.222137  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 35.334749
# -----------------------------------------------
# avg val loss per batch: 35.517318
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 45.137100  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 29.074400
# -----------------------------------------------
# avg val loss per batch: 29.782083
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 44.352333  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 26.697755
# -----------------------------------------------
# avg val loss per batch: 27.471888
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 43.875019  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 29.592555
# -----------------------------------------------
# avg val loss per batch: 29.930832
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 62.908745  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 24.519507
# -----------------------------------------------
# avg val loss per batch: 25.183942
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 35.068214  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 24.916174
# -----------------------------------------------
# avg val loss per batch: 25.186188
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 51.175125  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 23.061836
# -----------------------------------------------
# avg val loss per batch: 23.214659
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 41.438480  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 21.519668
# -----------------------------------------------
# avg val loss per batch: 21.887339
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 32.645229  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 18.483792
# -----------------------------------------------
# avg val loss per batch: 19.027496
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 28.572269  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 18.806756
# -----------------------------------------------
# avg val loss per batch: 19.167294
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 45.209587  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 16.291020
# -----------------------------------------------
# avg val loss per batch: 16.781789
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 38.364948  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 16.567939
# -----------------------------------------------
# avg val loss per batch: 16.890585
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 53.205143  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 15.739426
# -----------------------------------------------
# avg val loss per batch: 15.968328
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 20.038454  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 12.504936
# -----------------------------------------------
# avg val loss per batch: 12.934900
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 21.343243  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 12.166452
# -----------------------------------------------
# avg val loss per batch: 12.435932
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 23.520069  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 9.537119
# -----------------------------------------------
# avg val loss per batch: 9.933209
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 29.137459  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 10.420668
# -----------------------------------------------
# avg val loss per batch: 10.627026
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 32.265957  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 9.165819
# -----------------------------------------------
# avg val loss per batch: 9.444745
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 25.939022  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 6.445687
# -----------------------------------------------
# avg val loss per batch: 6.814972
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 21.095613  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 6.770511
# -----------------------------------------------
# avg val loss per batch: 7.076047
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 22.735954  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 8.495978
# -----------------------------------------------
# avg val loss per batch: 8.628390
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 24.220011  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 5.753661
# -----------------------------------------------
# avg val loss per batch: 5.904216
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 25.220501  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 4.373290
# -----------------------------------------------
# avg val loss per batch: 4.513184
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 16.686861  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 6.936344
# -----------------------------------------------
# avg val loss per batch: 7.032818
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 20.062605  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 5.490451
# -----------------------------------------------
# avg val loss per batch: 5.612094
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 15.479446  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.891315
# -----------------------------------------------
# avg val loss per batch: 4.012115
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 18.537830  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 5.220232
# -----------------------------------------------
# avg val loss per batch: 5.320082
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 20.082005  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 5.494680
# -----------------------------------------------
# avg val loss per batch: 5.558488
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 21.961952  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 4.905811
# -----------------------------------------------
# avg val loss per batch: 4.985676
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 17.311178  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.094281
# -----------------------------------------------
# avg val loss per batch: 3.176953
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 19.331963  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.655237
# -----------------------------------------------
# avg val loss per batch: 3.727902
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 11.587547  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.812450
# -----------------------------------------------
# avg val loss per batch: 3.878443
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 14.507441  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.434042
# -----------------------------------------------
# avg val loss per batch: 3.502252
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 18.759512  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.718187
# -----------------------------------------------
# avg val loss per batch: 3.785620
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 14.562233  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.401260
# -----------------------------------------------
# avg val loss per batch: 3.462973
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 13.256151  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.649256
# -----------------------------------------------
# avg val loss per batch: 3.711610
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 17.271776  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.769495
# -----------------------------------------------
# avg val loss per batch: 2.828431
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 19.978985  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.966335
# -----------------------------------------------
# avg val loss per batch: 3.001284
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 15.387792  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.666122
# -----------------------------------------------
# avg val loss per batch: 2.708447
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 18.757431  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.011777
# -----------------------------------------------
# avg val loss per batch: 3.064027
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 15.774088  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.178843
# -----------------------------------------------
# avg val loss per batch: 3.231672
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 17.507755  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 4.053110
# -----------------------------------------------
# avg val loss per batch: 4.110854
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 12.752495  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.833931
# -----------------------------------------------
# avg val loss per batch: 2.881484
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 15.577797  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.382387
# -----------------------------------------------
# avg val loss per batch: 2.436576
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 12.995026  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.912822
# -----------------------------------------------
# avg val loss per batch: 2.986109
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 17.610947  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.207772
# -----------------------------------------------
# avg val loss per batch: 2.272542
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 11.234629  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.212778
# -----------------------------------------------
# avg val loss per batch: 2.260622
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 16.484261  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.426433
# -----------------------------------------------
# avg val loss per batch: 2.473657
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 8.693221  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.648601
# -----------------------------------------------
# avg val loss per batch: 2.707758
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 12.521070  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.527847
# -----------------------------------------------
# avg val loss per batch: 1.580557
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 12.402725  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.911300
# -----------------------------------------------
# avg val loss per batch: 1.980592
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 15.437290  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.585898
# -----------------------------------------------
# avg val loss per batch: 2.656169
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 9.628633  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.938675
# -----------------------------------------------
# avg val loss per batch: 1.981591
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 13.743876  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.408975
# -----------------------------------------------
# avg val loss per batch: 2.474344
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 18.154991  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.992438
# -----------------------------------------------
# avg val loss per batch: 2.022614
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 15.371181  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.427189
# -----------------------------------------------
# avg val loss per batch: 2.484240
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 11.298938  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.752316
# -----------------------------------------------
# avg val loss per batch: 1.793312
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 10.329256  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.281362
# -----------------------------------------------
# avg val loss per batch: 2.343159
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 11.141482  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.172644
# -----------------------------------------------
# avg val loss per batch: 2.223025
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 16.461370  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.249730
# -----------------------------------------------
# avg val loss per batch: 2.311154
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 15.054410  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.800264
# -----------------------------------------------
# avg val loss per batch: 1.851442
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 11.319855  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.881430
# -----------------------------------------------
# avg val loss per batch: 1.923996
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 11.788852  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.604164
# -----------------------------------------------
# avg val loss per batch: 1.653553
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 12.873955  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.622751
# -----------------------------------------------
# avg val loss per batch: 2.728529
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 11.459748  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.181360
# -----------------------------------------------
# avg val loss per batch: 2.240968
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 12.385176  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.612622
# -----------------------------------------------
# avg val loss per batch: 1.686598
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 10.270553  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.886157
# -----------------------------------------------
# avg val loss per batch: 1.965074
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 11.597759  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.529080
# -----------------------------------------------
# avg val loss per batch: 1.598386
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 12.697689  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.145512
# -----------------------------------------------
# avg val loss per batch: 3.267417
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 10.757530  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.947835
# -----------------------------------------------
# avg val loss per batch: 2.023048
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 9.494751  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.751633
# -----------------------------------------------
# avg val loss per batch: 1.842209
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 12.330757  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.598413
# -----------------------------------------------
# avg val loss per batch: 1.657631
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 9.315098  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.493117
# -----------------------------------------------
# avg val loss per batch: 1.564926
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 15.376040  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.570116
# -----------------------------------------------
# avg val loss per batch: 1.654750
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 10.895781  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.985355
# -----------------------------------------------
# avg val loss per batch: 2.098999
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 14.195279  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.818313
# -----------------------------------------------
# avg val loss per batch: 1.916656
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 10.676094  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.504719
# -----------------------------------------------
# avg val loss per batch: 1.584727
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 7.880321  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.972330
# -----------------------------------------------
# avg val loss per batch: 2.071751
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 8.456560  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.312493
# -----------------------------------------------
# avg val loss per batch: 1.399570
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 6.356814  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.779271
# -----------------------------------------------
# avg val loss per batch: 1.880180
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 10.914122  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.648790
# -----------------------------------------------
# avg val loss per batch: 1.750229
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 15.587432  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.112008
# -----------------------------------------------
# avg val loss per batch: 2.220211
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 8.197219  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.820463
# -----------------------------------------------
# avg val loss per batch: 1.931822
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 8.139290  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.473888
# -----------------------------------------------
# avg val loss per batch: 1.562934
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 7.759948  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.342633
# -----------------------------------------------
# avg val loss per batch: 1.423410
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 9.229258  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.550727
# -----------------------------------------------
# avg val loss per batch: 1.654619
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 11.037379  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.730410
# -----------------------------------------------
# avg val loss per batch: 1.857138
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 10.190248  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.699579
# -----------------------------------------------
# avg val loss per batch: 1.810496
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 11.139621  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.716758
# -----------------------------------------------
# avg val loss per batch: 1.823958
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 7.379944  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.205233
# -----------------------------------------------
# avg val loss per batch: 1.286132
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 9.741065  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.682817
# -----------------------------------------------
# avg val loss per batch: 1.799833
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 9.423008  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.270860
# -----------------------------------------------
# avg val loss per batch: 1.361979
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 12.251063  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.447883
# -----------------------------------------------
# avg val loss per batch: 1.549408
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 8.022088  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.125242
# -----------------------------------------------
# avg val loss per batch: 1.208867
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 11.192843  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.443938
# -----------------------------------------------
# avg val loss per batch: 1.544421
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 11.306115  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.877347
# -----------------------------------------------
# avg val loss per batch: 2.012440
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 7.594629  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.607091
# -----------------------------------------------
# avg val loss per batch: 1.729666
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 12.590322  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.316088
# -----------------------------------------------
# avg val loss per batch: 1.423065
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 107
# -----------------------------------------------
# current batch loss: 10.648536  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.609559
# -----------------------------------------------
# avg val loss per batch: 1.717305
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 108
# -----------------------------------------------
# current batch loss: 8.612523  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.487484
# -----------------------------------------------
# avg val loss per batch: 1.602304
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 109
# -----------------------------------------------
# current batch loss: 11.970086  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.202002
# -----------------------------------------------
# avg val loss per batch: 1.292871
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 110
# -----------------------------------------------
# current batch loss: 7.775014  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.144822
# -----------------------------------------------
# avg val loss per batch: 1.234768
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 111
# -----------------------------------------------
# current batch loss: 10.308194  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.781330
# -----------------------------------------------
# avg val loss per batch: 1.907106
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 112
# -----------------------------------------------
# current batch loss: 8.770329  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.438809
# -----------------------------------------------
# avg val loss per batch: 1.531937
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 113
# -----------------------------------------------
# current batch loss: 7.436532  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.286311
# -----------------------------------------------
# avg val loss per batch: 1.377657
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 114
# -----------------------------------------------
# current batch loss: 10.030990  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.852819
# -----------------------------------------------
# avg val loss per batch: 1.981760
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 115
# -----------------------------------------------
# current batch loss: 9.121407  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.273254
# -----------------------------------------------
# avg val loss per batch: 1.391747
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 7.153134  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.334361
# -----------------------------------------------
# avg val loss per batch: 1.442182
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 10.955627  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.281148
# -----------------------------------------------
# avg val loss per batch: 1.382173
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 9.783604  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.291271
# -----------------------------------------------
# avg val loss per batch: 1.411901
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 10.772567  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.382105
# -----------------------------------------------
# avg val loss per batch: 1.506691
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 7.094284  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.463000
# -----------------------------------------------
# avg val loss per batch: 1.594127
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 8.648029  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.511973
# -----------------------------------------------
# avg val loss per batch: 1.635741
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 9.693825  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.225935
# -----------------------------------------------
# avg val loss per batch: 1.341821
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 9.981021  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.138373
# -----------------------------------------------
# avg val loss per batch: 1.235524
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 8.932740  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.490789
# -----------------------------------------------
# avg val loss per batch: 1.612262
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 9.423917  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.366681
# -----------------------------------------------
# avg val loss per batch: 1.484590
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 8.864618  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.293788
# -----------------------------------------------
# avg val loss per batch: 1.411239
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 8.078738  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.509486
# -----------------------------------------------
# avg val loss per batch: 1.639164
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 7.207801  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.435046
# -----------------------------------------------
# avg val loss per batch: 1.554951
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 7.025176  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.062539
# -----------------------------------------------
# avg val loss per batch: 1.163442
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 11.379452  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.727724
# -----------------------------------------------
# avg val loss per batch: 1.862347
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 131
# -----------------------------------------------
# current batch loss: 7.738829  [    0/ 1000]
# -----------------------------------------------
# ...
# |
# -----------------------------------------------
# Epoch 1457
# -----------------------------------------------
# current batch loss: 1.311165  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.183253
# -----------------------------------------------
# avg val loss per batch: 0.239439
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1458
# -----------------------------------------------
# current batch loss: 1.700810  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.248555
# -----------------------------------------------
# avg val loss per batch: 0.311292
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1459
# -----------------------------------------------
# current batch loss: 1.519120  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.213229
# -----------------------------------------------
# avg val loss per batch: 0.270787
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1460
# -----------------------------------------------
# current batch loss: 1.640325  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.233732
# -----------------------------------------------
# avg val loss per batch: 0.292511
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1461
# -----------------------------------------------
# current batch loss: 1.620793  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.232754
# -----------------------------------------------
# avg val loss per batch: 0.298188
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1462
# -----------------------------------------------
# current batch loss: 1.492837  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.219335
# -----------------------------------------------
# avg val loss per batch: 0.282557
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1463
# -----------------------------------------------
# current batch loss: 1.469175  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.254664
# -----------------------------------------------
# avg val loss per batch: 0.318867
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1464
# -----------------------------------------------
# current batch loss: 1.392083  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.217864
# -----------------------------------------------
# avg val loss per batch: 0.276829
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1465
# -----------------------------------------------
# current batch loss: 1.492932  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.273396
# -----------------------------------------------
# avg val loss per batch: 0.335728
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1466
# -----------------------------------------------
# current batch loss: 1.487366  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.240522
# -----------------------------------------------
# avg val loss per batch: 0.301460
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1467
# -----------------------------------------------
# current batch loss: 2.091186  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.258265
# -----------------------------------------------
# avg val loss per batch: 0.323414
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1468
# -----------------------------------------------
# current batch loss: 1.786218  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.258628
# -----------------------------------------------
# avg val loss per batch: 0.317875
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1469
# -----------------------------------------------
# current batch loss: 1.510691  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.218662
# -----------------------------------------------
# avg val loss per batch: 0.277197
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1470
# -----------------------------------------------
# current batch loss: 1.359139  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.243410
# -----------------------------------------------
# avg val loss per batch: 0.303138
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1471
# -----------------------------------------------
# current batch loss: 1.603428  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.226832
# -----------------------------------------------
# avg val loss per batch: 0.285353
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1472
# -----------------------------------------------
# current batch loss: 1.428823  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.220296
# -----------------------------------------------
# avg val loss per batch: 0.279460
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1473
# -----------------------------------------------
# current batch loss: 1.319408  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.244324
# -----------------------------------------------
# avg val loss per batch: 0.307225
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1474
# -----------------------------------------------
# current batch loss: 1.223441  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.227723
# -----------------------------------------------
# avg val loss per batch: 0.286870
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1475
# -----------------------------------------------
# current batch loss: 1.649500  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.222359
# -----------------------------------------------
# avg val loss per batch: 0.277745
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1476
# -----------------------------------------------
# current batch loss: 1.914757  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.300433
# -----------------------------------------------
# avg val loss per batch: 0.363887
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1477
# -----------------------------------------------
# current batch loss: 1.493233  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.242416
# -----------------------------------------------
# avg val loss per batch: 0.300420
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1478
# -----------------------------------------------
# current batch loss: 1.772036  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.291222
# -----------------------------------------------
# avg val loss per batch: 0.361192
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1479
# -----------------------------------------------
# current batch loss: 1.366955  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.228831
# -----------------------------------------------
# avg val loss per batch: 0.292638
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1480
# -----------------------------------------------
# current batch loss: 1.673439  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.259271
# -----------------------------------------------
# avg val loss per batch: 0.322006
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1481
# -----------------------------------------------
# current batch loss: 1.459178  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.210922
# -----------------------------------------------
# avg val loss per batch: 0.272540
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1482
# -----------------------------------------------
# current batch loss: 1.423503  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.221836
# -----------------------------------------------
# avg val loss per batch: 0.282411
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1483
# -----------------------------------------------
# current batch loss: 1.378386  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.233715
# -----------------------------------------------
# avg val loss per batch: 0.299078
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1484
# -----------------------------------------------
# current batch loss: 1.533151  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.221217
# -----------------------------------------------
# avg val loss per batch: 0.281142
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1485
# -----------------------------------------------
# current batch loss: 1.508419  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.274757
# -----------------------------------------------
# avg val loss per batch: 0.340711
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1486
# -----------------------------------------------
# current batch loss: 1.345859  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.215035
# -----------------------------------------------
# avg val loss per batch: 0.271752
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1487
# -----------------------------------------------
# current batch loss: 1.343593  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.229958
# -----------------------------------------------
# avg val loss per batch: 0.286380
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1488
# -----------------------------------------------
# current batch loss: 1.670971  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.195650
# -----------------------------------------------
# avg val loss per batch: 0.250826
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1489
# -----------------------------------------------
# current batch loss: 1.746930  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.270340
# -----------------------------------------------
# avg val loss per batch: 0.335175
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1490
# -----------------------------------------------
# current batch loss: 1.531737  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.273228
# -----------------------------------------------
# avg val loss per batch: 0.331922
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1491
# -----------------------------------------------
# current batch loss: 1.247002  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.237257
# -----------------------------------------------
# avg val loss per batch: 0.294759
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1492
# -----------------------------------------------
# current batch loss: 1.807274  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.224479
# -----------------------------------------------
# avg val loss per batch: 0.282310
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1493
# -----------------------------------------------
# current batch loss: 1.112500  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.201034
# -----------------------------------------------
# avg val loss per batch: 0.254430
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1494
# -----------------------------------------------
# current batch loss: 1.438352  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.223883
# -----------------------------------------------
# avg val loss per batch: 0.281886
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1495
# -----------------------------------------------
# current batch loss: 0.852556  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.244567
# -----------------------------------------------
# avg val loss per batch: 0.303080
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1496
# -----------------------------------------------
# current batch loss: 1.397443  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.219514
# -----------------------------------------------
# avg val loss per batch: 0.276716
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1497
# -----------------------------------------------
# current batch loss: 1.645197  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.257241
# -----------------------------------------------
# avg val loss per batch: 0.318112
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1498
# -----------------------------------------------
# current batch loss: 1.197048  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.192046
# -----------------------------------------------
# avg val loss per batch: 0.246492
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1499
# -----------------------------------------------
# current batch loss: 1.360601  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.230735
# -----------------------------------------------
# avg val loss per batch: 0.293652
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1500
# -----------------------------------------------
# current batch loss: 1.299037  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.238381
# -----------------------------------------------
# avg val loss per batch: 0.301796
# -----------------------------------------------
# |
# Done!

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses_dr, label="train loss", color=c1 )
axs.plot( val_losses_dr, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = [ int(x) for x in axs.get_xticks() ]
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# Clearly, we can see that dropout has completely prevented over-training!

# %% [markdown]
# ### L2 regularisation
#
# Similar to dropout L2 regularisation is a method which can be used to reduce overfitting.
#
# It simply works by adding a term of the form: ~$\lambda|\omega|^2 $
# to the loss function. In our case we get:
#
# $$L = MSE + \lambda|\omega|^2$$
#
# where $\lambda$ is an additional hyperparameter.
#
# One possible interpretation of L2-regularisation is having a normal prior over weight space where $\lambda$ is related to the width of the prior and the central value is set to 0. This normal prior resctricts the model complexity by punishing models with a weight configuration far away from its central value of 0.
#
# -----------------------------------

# %% [markdown]
# Let's just copy paste everything from before...

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# define parameters
ipt_dim = 20
opt_dim = 1
hdn_dim = 50
batch_size = 64
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 1500

# re-initialise the model and the optimizer
hdn_dim = 50
model = amp_net( hdn_dim=hdn_dim ).to(device) # model without Dropout!
learning_rate = 5e-4

# %% [markdown]
# In pytorch L2 regularisation can be added via the argument 'weight_decay' of the optimizer.

# %%
weight_decay = 1e-1
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate, weight_decay=weight_decay )

# %% [markdown]
# As a side note:
#
# An alternative explicit implementation would be:
#
# weight_decay = 1e-2\
# l2_norm = sum(torch.linalg.norm(p, 2) for p in model.parameters())
#
# loss = loss + weight_decay * l2_norm

# %%
seperator()
print( "model architecture ")
seperator()
print( model )

# track train and val losses
trn_losses_l2 = []
val_losses_l2 = []

for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model, loss_fn, optimizer )
    seperator()
    trn_loss = trn_pass( trn_dataloader, model, loss_fn )
    trn_losses_l2.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model, loss_fn )
    val_losses_l2.append( val_loss )
    seperator()
    print( "|" )
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=50, out_features=50, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 217.119827  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 211.754169
# -----------------------------------------------
# avg val loss per batch: 213.837885
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 209.473083  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 202.308769
# -----------------------------------------------
# avg val loss per batch: 203.879199
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 197.651718  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 170.698551
# -----------------------------------------------
# avg val loss per batch: 171.318057
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 169.481079  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 84.398150
# -----------------------------------------------
# avg val loss per batch: 83.947512
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 91.849037  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 37.047930
# -----------------------------------------------
# avg val loss per batch: 41.814281
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 39.410603  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 31.023748
# -----------------------------------------------
# avg val loss per batch: 33.263121
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 25.025253  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 28.162609
# -----------------------------------------------
# avg val loss per batch: 30.825680
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 25.573086  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 26.511140
# -----------------------------------------------
# avg val loss per batch: 28.923279
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 23.803602  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 24.499147
# -----------------------------------------------
# avg val loss per batch: 27.178025
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 19.033939  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 22.934595
# -----------------------------------------------
# avg val loss per batch: 25.455171
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 23.258125  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 21.544800
# -----------------------------------------------
# avg val loss per batch: 23.387831
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 18.073830  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 19.086786
# -----------------------------------------------
# avg val loss per batch: 21.245712
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 17.985561  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 16.933548
# -----------------------------------------------
# avg val loss per batch: 18.758460
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 15.690050  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 14.320413
# -----------------------------------------------
# avg val loss per batch: 16.210603
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 17.018106  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 11.459856
# -----------------------------------------------
# avg val loss per batch: 12.802921
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 13.196517  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 8.600226
# -----------------------------------------------
# avg val loss per batch: 10.086027
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 5.932156  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 5.593724
# -----------------------------------------------
# avg val loss per batch: 6.275335
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 7.328845  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.623997
# -----------------------------------------------
# avg val loss per batch: 4.004555
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 4.716654  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.891259
# -----------------------------------------------
# avg val loss per batch: 2.333540
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 2.187057  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.258354
# -----------------------------------------------
# avg val loss per batch: 1.614720
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 1.930717  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.969959
# -----------------------------------------------
# avg val loss per batch: 1.318490
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 0.800573  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.773776
# -----------------------------------------------
# avg val loss per batch: 1.059514
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 0.586296  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.623790
# -----------------------------------------------
# avg val loss per batch: 0.795130
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 0.484733  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.550877
# -----------------------------------------------
# avg val loss per batch: 0.755746
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 0.818390  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.482613
# -----------------------------------------------
# avg val loss per batch: 0.629468
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 0.645429  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.453242
# -----------------------------------------------
# avg val loss per batch: 0.607242
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 0.403705  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.426406
# -----------------------------------------------
# avg val loss per batch: 0.565798
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 0.410168  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.408857
# -----------------------------------------------
# avg val loss per batch: 0.524091
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 0.387885  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.391031
# -----------------------------------------------
# avg val loss per batch: 0.501888
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 0.284041  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.368802
# -----------------------------------------------
# avg val loss per batch: 0.502735
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 0.268816  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.375888
# -----------------------------------------------
# avg val loss per batch: 0.483886
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 0.364671  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.342712
# -----------------------------------------------
# avg val loss per batch: 0.490351
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 0.445834  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.336754
# -----------------------------------------------
# avg val loss per batch: 0.482137
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 0.340418  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.322488
# -----------------------------------------------
# avg val loss per batch: 0.466382
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 0.278577  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.319236
# -----------------------------------------------
# avg val loss per batch: 0.443116
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 0.283906  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.321039
# -----------------------------------------------
# avg val loss per batch: 0.476860
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 0.349960  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.311099
# -----------------------------------------------
# avg val loss per batch: 0.440422
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 0.237579  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.321675
# -----------------------------------------------
# avg val loss per batch: 0.500313
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 0.301939  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.325731
# -----------------------------------------------
# avg val loss per batch: 0.516010
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 0.307041  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.296950
# -----------------------------------------------
# avg val loss per batch: 0.420364
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 0.214519  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.293330
# -----------------------------------------------
# avg val loss per batch: 0.442463
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 0.215763  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.279538
# -----------------------------------------------
# avg val loss per batch: 0.427883
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 0.291091  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.279010
# -----------------------------------------------
# avg val loss per batch: 0.420112
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 0.267518  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.287584
# -----------------------------------------------
# avg val loss per batch: 0.465319
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 0.339245  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.280458
# -----------------------------------------------
# avg val loss per batch: 0.403734
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 0.254548  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.273745
# -----------------------------------------------
# avg val loss per batch: 0.408687
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 0.195824  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.268404
# -----------------------------------------------
# avg val loss per batch: 0.426102
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 0.234374  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.267581
# -----------------------------------------------
# avg val loss per batch: 0.403294
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 0.247591  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.276596
# -----------------------------------------------
# avg val loss per batch: 0.403148
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 0.266620  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.266164
# -----------------------------------------------
# avg val loss per batch: 0.420495
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 0.253944  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.276042
# -----------------------------------------------
# avg val loss per batch: 0.395670
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 0.268370  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.265540
# -----------------------------------------------
# avg val loss per batch: 0.391020
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 0.224313  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.264340
# -----------------------------------------------
# avg val loss per batch: 0.406006
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 0.234261  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.283430
# -----------------------------------------------
# avg val loss per batch: 0.461278
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 0.406594  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.251432
# -----------------------------------------------
# avg val loss per batch: 0.408797
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 0.158953  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.253717
# -----------------------------------------------
# avg val loss per batch: 0.393958
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 0.205838  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.251094
# -----------------------------------------------
# avg val loss per batch: 0.400123
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 0.215226  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.254365
# -----------------------------------------------
# avg val loss per batch: 0.384770
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 0.229074  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.243768
# -----------------------------------------------
# avg val loss per batch: 0.395351
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 0.290883  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.272875
# -----------------------------------------------
# avg val loss per batch: 0.383090
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 0.362471  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.246834
# -----------------------------------------------
# avg val loss per batch: 0.415150
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 0.285708  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.240648
# -----------------------------------------------
# avg val loss per batch: 0.401909
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 0.234051  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.245871
# -----------------------------------------------
# avg val loss per batch: 0.380514
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 0.218723  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.237552
# -----------------------------------------------
# avg val loss per batch: 0.398288
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 0.287416  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.237359
# -----------------------------------------------
# avg val loss per batch: 0.377617
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 0.198381  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.245757
# -----------------------------------------------
# avg val loss per batch: 0.372806
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 0.242513  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.232572
# -----------------------------------------------
# avg val loss per batch: 0.381609
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 0.195166  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.249684
# -----------------------------------------------
# avg val loss per batch: 0.378989
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 0.273260  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.228013
# -----------------------------------------------
# avg val loss per batch: 0.379134
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 0.161561  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.229097
# -----------------------------------------------
# avg val loss per batch: 0.380105
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 0.154932  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.233407
# -----------------------------------------------
# avg val loss per batch: 0.365157
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 0.161285  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.234661
# -----------------------------------------------
# avg val loss per batch: 0.362064
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 0.278151  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.233634
# -----------------------------------------------
# avg val loss per batch: 0.396634
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 0.214124  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.245956
# -----------------------------------------------
# avg val loss per batch: 0.377890
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 0.244610  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.231868
# -----------------------------------------------
# avg val loss per batch: 0.395325
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 0.170891  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.223971
# -----------------------------------------------
# avg val loss per batch: 0.388707
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 0.197584  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.224893
# -----------------------------------------------
# avg val loss per batch: 0.385380
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 0.288905  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.252814
# -----------------------------------------------
# avg val loss per batch: 0.365685
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 0.348152  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.216462
# -----------------------------------------------
# avg val loss per batch: 0.365241
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 0.300279  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.226193
# -----------------------------------------------
# avg val loss per batch: 0.358654
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 0.257221  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.231361
# -----------------------------------------------
# avg val loss per batch: 0.405434
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 0.250999  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.220852
# -----------------------------------------------
# avg val loss per batch: 0.371468
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 0.247611  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.220821
# -----------------------------------------------
# avg val loss per batch: 0.384965
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 0.226409  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.212533
# -----------------------------------------------
# avg val loss per batch: 0.362665
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 0.260762  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.214610
# -----------------------------------------------
# avg val loss per batch: 0.365485
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 0.200302  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.214084
# -----------------------------------------------
# avg val loss per batch: 0.370855
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 0.200267  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.212614
# -----------------------------------------------
# avg val loss per batch: 0.350673
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 0.158461  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.299149
# -----------------------------------------------
# avg val loss per batch: 0.397777
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 0.217955  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.232047
# -----------------------------------------------
# avg val loss per batch: 0.399418
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 0.250921  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.213845
# -----------------------------------------------
# avg val loss per batch: 0.360372
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 0.204215  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.207369
# -----------------------------------------------
# avg val loss per batch: 0.349999
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 0.166624  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.213496
# -----------------------------------------------
# avg val loss per batch: 0.337862
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 0.320632  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.214771
# -----------------------------------------------
# avg val loss per batch: 0.378623
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 0.197209  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.220377
# -----------------------------------------------
# avg val loss per batch: 0.352050
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 0.268123  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.207086
# -----------------------------------------------
# avg val loss per batch: 0.344770
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 0.212388  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.206208
# -----------------------------------------------
# avg val loss per batch: 0.350701
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 0.312225  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.232988
# -----------------------------------------------
# avg val loss per batch: 0.404961
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 0.172913  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.206672
# -----------------------------------------------
# avg val loss per batch: 0.347040
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 0.231948  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.201105
# -----------------------------------------------
# avg val loss per batch: 0.342997
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 0.246677  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.208861
# -----------------------------------------------
# avg val loss per batch: 0.336552
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 0.194434  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.217725
# -----------------------------------------------
# avg val loss per batch: 0.345023
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 0.270995  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.219634
# -----------------------------------------------
# avg val loss per batch: 0.338086
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 0.247308  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.216377
# -----------------------------------------------
# avg val loss per batch: 0.338497
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 0.284052  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.201421
# -----------------------------------------------
# avg val loss per batch: 0.339835
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 0.206875  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.228960
# -----------------------------------------------
# avg val loss per batch: 0.344631
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 0.232011  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.202135
# -----------------------------------------------
# avg val loss per batch: 0.346433
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 107
# -----------------------------------------------
# current batch loss: 0.261234  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.209782
# -----------------------------------------------
# avg val loss per batch: 0.344348
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 108
# -----------------------------------------------
# current batch loss: 0.219373  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.206844
# -----------------------------------------------
# avg val loss per batch: 0.331451
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 109
# -----------------------------------------------
# current batch loss: 0.142671  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.210548
# -----------------------------------------------
# avg val loss per batch: 0.366036
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 110
# -----------------------------------------------
# current batch loss: 0.236538  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.201135
# -----------------------------------------------
# avg val loss per batch: 0.346570
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 111
# -----------------------------------------------
# current batch loss: 0.253582  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.208481
# -----------------------------------------------
# avg val loss per batch: 0.332901
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 112
# -----------------------------------------------
# current batch loss: 0.191828  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.196593
# -----------------------------------------------
# avg val loss per batch: 0.340642
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 113
# -----------------------------------------------
# current batch loss: 0.190517  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.206391
# -----------------------------------------------
# avg val loss per batch: 0.364236
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 114
# -----------------------------------------------
# current batch loss: 0.170873  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.212385
# -----------------------------------------------
# avg val loss per batch: 0.367506
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 115
# -----------------------------------------------
# current batch loss: 0.253467  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.197991
# -----------------------------------------------
# avg val loss per batch: 0.345738
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 0.169527  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.197411
# -----------------------------------------------
# avg val loss per batch: 0.333181
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 0.196403  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.230411
# -----------------------------------------------
# avg val loss per batch: 0.333294
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 0.132572  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.198105
# -----------------------------------------------
# avg val loss per batch: 0.344716
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 0.145200  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.212188
# -----------------------------------------------
# avg val loss per batch: 0.369340
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 0.149230  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.218970
# -----------------------------------------------
# avg val loss per batch: 0.329872
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 0.172671  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.198678
# -----------------------------------------------
# avg val loss per batch: 0.319549
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 0.238826  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.196558
# -----------------------------------------------
# avg val loss per batch: 0.345180
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 0.158976  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.193917
# -----------------------------------------------
# avg val loss per batch: 0.336903
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 0.267030  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.197007
# -----------------------------------------------
# avg val loss per batch: 0.315093
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 0.193044  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.207572
# -----------------------------------------------
# avg val loss per batch: 0.330607
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 0.175867  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.215547
# -----------------------------------------------
# avg val loss per batch: 0.365689
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 0.284049  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.195963
# -----------------------------------------------
# avg val loss per batch: 0.328865
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 0.261410  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.195996
# -----------------------------------------------
# avg val loss per batch: 0.314974
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 0.163644  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.194018
# -----------------------------------------------
# avg val loss per batch: 0.324698
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 0.164267  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.215154
# -----------------------------------------------
# avg val loss per batch: 0.372662
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 131
# -----------------------------------------------
# current batch loss: 0.226383  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.187894
# -----------------------------------------------
# avg val loss per batch: 0.326568
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 132
# ...
# |
# -----------------------------------------------
# Epoch 1457
# -----------------------------------------------
# current batch loss: 0.104201  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.092577
# -----------------------------------------------
# avg val loss per batch: 0.159754
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1458
# -----------------------------------------------
# current batch loss: 0.103311  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.094001
# -----------------------------------------------
# avg val loss per batch: 0.160347
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1459
# -----------------------------------------------
# current batch loss: 0.136426  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.124859
# -----------------------------------------------
# avg val loss per batch: 0.201175
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1460
# -----------------------------------------------
# current batch loss: 0.130249  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.102804
# -----------------------------------------------
# avg val loss per batch: 0.177671
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1461
# -----------------------------------------------
# current batch loss: 0.093858  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.102186
# -----------------------------------------------
# avg val loss per batch: 0.173609
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1462
# -----------------------------------------------
# current batch loss: 0.091941  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.103947
# -----------------------------------------------
# avg val loss per batch: 0.178166
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1463
# -----------------------------------------------
# current batch loss: 0.090076  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.106263
# -----------------------------------------------
# avg val loss per batch: 0.176611
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1464
# -----------------------------------------------
# current batch loss: 0.119240  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.091075
# -----------------------------------------------
# avg val loss per batch: 0.158097
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1465
# -----------------------------------------------
# current batch loss: 0.133922  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.090379
# -----------------------------------------------
# avg val loss per batch: 0.157472
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1466
# -----------------------------------------------
# current batch loss: 0.101500  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.093569
# -----------------------------------------------
# avg val loss per batch: 0.158201
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1467
# -----------------------------------------------
# current batch loss: 0.087103  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.099179
# -----------------------------------------------
# avg val loss per batch: 0.164642
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1468
# -----------------------------------------------
# current batch loss: 0.095095  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.093498
# -----------------------------------------------
# avg val loss per batch: 0.160536
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1469
# -----------------------------------------------
# current batch loss: 0.099445  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.094056
# -----------------------------------------------
# avg val loss per batch: 0.164981
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1470
# -----------------------------------------------
# current batch loss: 0.096134  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.107263
# -----------------------------------------------
# avg val loss per batch: 0.176134
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1471
# -----------------------------------------------
# current batch loss: 0.102263  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.103022
# -----------------------------------------------
# avg val loss per batch: 0.175230
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1472
# -----------------------------------------------
# current batch loss: 0.124664  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.130654
# -----------------------------------------------
# avg val loss per batch: 0.194843
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1473
# -----------------------------------------------
# current batch loss: 0.177114  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.091648
# -----------------------------------------------
# avg val loss per batch: 0.158759
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1474
# -----------------------------------------------
# current batch loss: 0.082723  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.095405
# -----------------------------------------------
# avg val loss per batch: 0.166436
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1475
# -----------------------------------------------
# current batch loss: 0.097337  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.108007
# -----------------------------------------------
# avg val loss per batch: 0.167213
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1476
# -----------------------------------------------
# current batch loss: 0.074923  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.095104
# -----------------------------------------------
# avg val loss per batch: 0.159219
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1477
# -----------------------------------------------
# current batch loss: 0.095952  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.092830
# -----------------------------------------------
# avg val loss per batch: 0.155370
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1478
# -----------------------------------------------
# current batch loss: 0.067415  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.092771
# -----------------------------------------------
# avg val loss per batch: 0.156707
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1479
# -----------------------------------------------
# current batch loss: 0.068050  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.093466
# -----------------------------------------------
# avg val loss per batch: 0.164243
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1480
# -----------------------------------------------
# current batch loss: 0.075334  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.107690
# -----------------------------------------------
# avg val loss per batch: 0.171985
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1481
# -----------------------------------------------
# current batch loss: 0.091550  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.099353
# -----------------------------------------------
# avg val loss per batch: 0.166722
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1482
# -----------------------------------------------
# current batch loss: 0.121549  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.105967
# -----------------------------------------------
# avg val loss per batch: 0.168871
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1483
# -----------------------------------------------
# current batch loss: 0.108151  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.090292
# -----------------------------------------------
# avg val loss per batch: 0.156353
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1484
# -----------------------------------------------
# current batch loss: 0.070124  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.092336
# -----------------------------------------------
# avg val loss per batch: 0.158429
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1485
# -----------------------------------------------
# current batch loss: 0.072576  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.095478
# -----------------------------------------------
# avg val loss per batch: 0.161674
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1486
# -----------------------------------------------
# current batch loss: 0.135315  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.176741
# -----------------------------------------------
# avg val loss per batch: 0.236861
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1487
# -----------------------------------------------
# current batch loss: 0.150492  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.102585
# -----------------------------------------------
# avg val loss per batch: 0.170243
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1488
# -----------------------------------------------
# current batch loss: 0.062077  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.097286
# -----------------------------------------------
# avg val loss per batch: 0.157698
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1489
# -----------------------------------------------
# current batch loss: 0.106413  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.104668
# -----------------------------------------------
# avg val loss per batch: 0.172881
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1490
# -----------------------------------------------
# current batch loss: 0.102926  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.093481
# -----------------------------------------------
# avg val loss per batch: 0.159943
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1491
# -----------------------------------------------
# current batch loss: 0.075368  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.094172
# -----------------------------------------------
# avg val loss per batch: 0.161185
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1492
# -----------------------------------------------
# current batch loss: 0.088508  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.092937
# -----------------------------------------------
# avg val loss per batch: 0.160175
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1493
# -----------------------------------------------
# current batch loss: 0.100752  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.111768
# -----------------------------------------------
# avg val loss per batch: 0.173365
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1494
# -----------------------------------------------
# current batch loss: 0.141675  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.090171
# -----------------------------------------------
# avg val loss per batch: 0.155003
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1495
# -----------------------------------------------
# current batch loss: 0.090121  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.089054
# -----------------------------------------------
# avg val loss per batch: 0.158926
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1496
# -----------------------------------------------
# current batch loss: 0.132295  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.090747
# -----------------------------------------------
# avg val loss per batch: 0.156949
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1497
# -----------------------------------------------
# current batch loss: 0.097086  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.090552
# -----------------------------------------------
# avg val loss per batch: 0.157712
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1498
# -----------------------------------------------
# current batch loss: 0.054331  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.091916
# -----------------------------------------------
# avg val loss per batch: 0.160465
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1499
# -----------------------------------------------
# current batch loss: 0.078968  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.090438
# -----------------------------------------------
# avg val loss per batch: 0.159827
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1500
# -----------------------------------------------
# current batch loss: 0.052692  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.126686
# -----------------------------------------------
# avg val loss per batch: 0.186617
# -----------------------------------------------
# |
# Done!

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses_l2, label="train loss", color=c1 )
axs.plot( val_losses_l2, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = [ int(x) for x in axs.get_xticks() ]
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# Clearly the L2 regularisation has worked in reducing the over-fitting!
#
# L1 regularisation should have a similar effect, try it out!

# %% [markdown]
# ### Early stopping
#
# As we saw in one of the previous plots in a training without any regularization the validation loss typically stops decreasing after a while (or in the worst case even starts increasing) while the training loss keeps on decreasining. The idea of Early Stopping is to simply stop the training when this happens.
#
# ------------
# Copy paste again..

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# define parameters
ipt_dim = 20
opt_dim = 1
hdn_dim = 50
batch_size = 64
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 1500

# re-initialise the model and the optimizer
hdn_dim = 50
model = amp_net( hdn_dim=hdn_dim ).to(device) # model without Dropout!
learning_rate = 5e-4
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate )

# %% [markdown]
# The trigger condition can be arbitrarily complicated but in its simpliest version we just compare the current value of the validation loss with the previous value. However, because the validation dataset is typically small and the validation loss therefore prone to statistical fluctuations, we should not immediately stop the training the first time the breaking condition is triggered. Instead, we introduce the new hyperparameter 'patience' which tells us how many epochs we want to wait before stopping the training.

# %%
seperator()
print( "model architecture ")
seperator()
print( model )

# track train and val losses
trn_losses_es = []
val_losses_es = []

# patience of EarlyStopping in number of epochs
patience = 4

# set counter to 0 for early stopping
trigger_counter = 0
val_loss_last = 1e10

for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model, loss_fn, optimizer )
    seperator()
    trn_loss = trn_pass( trn_dataloader, model, loss_fn )
    trn_losses_es.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model, loss_fn )
    val_losses_es.append( val_loss )
    
    #######################
    # early stopping
    if val_loss > val_loss_last:
        trigger_counter += 1
    else:
        trigger_counter = 0
        
    if trigger_counter >= patience:
        print("EarlyStopping got triggered! Stop training!")
        break
    
    val_loss_last = val_loss
    #######################
    
    seperator()
    print( "|" )
    
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=50, out_features=50, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 214.975861  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 211.139175
# -----------------------------------------------
# avg val loss per batch: 212.908908
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 210.390305  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 195.069190
# -----------------------------------------------
# avg val loss per batch: 196.344025
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 195.913361  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 142.831520
# -----------------------------------------------
# avg val loss per batch: 142.805366
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 145.499786  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 42.858092
# -----------------------------------------------
# avg val loss per batch: 43.529206
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 46.012760  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 35.075064
# -----------------------------------------------
# avg val loss per batch: 39.904993
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 18.220078  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 30.817674
# -----------------------------------------------
# avg val loss per batch: 33.190854
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 32.111183  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 29.011046
# -----------------------------------------------
# avg val loss per batch: 32.013746
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 22.379412  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 27.551171
# -----------------------------------------------
# avg val loss per batch: 29.964270
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 29.252848  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 25.847059
# -----------------------------------------------
# avg val loss per batch: 28.557511
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 28.448311  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 24.356695
# -----------------------------------------------
# avg val loss per batch: 26.909857
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 28.970146  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 22.734684
# -----------------------------------------------
# avg val loss per batch: 24.983033
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 25.318764  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 21.003587
# -----------------------------------------------
# avg val loss per batch: 23.139443
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 20.751183  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 19.076125
# -----------------------------------------------
# avg val loss per batch: 21.122049
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 15.843027  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 17.085011
# -----------------------------------------------
# avg val loss per batch: 18.984563
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 9.889556  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 14.968691
# -----------------------------------------------
# avg val loss per batch: 16.701004
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 15.478544  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 12.814478
# -----------------------------------------------
# avg val loss per batch: 14.348076
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 14.137152  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 10.614348
# -----------------------------------------------
# avg val loss per batch: 11.752303
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 10.964025  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 8.248607
# -----------------------------------------------
# avg val loss per batch: 9.485533
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 7.365772  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 6.293256
# -----------------------------------------------
# avg val loss per batch: 7.128973
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 3.621465  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 4.500650
# -----------------------------------------------
# avg val loss per batch: 5.223679
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 4.289221  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.214350
# -----------------------------------------------
# avg val loss per batch: 3.749675
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 2.974020  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.368208
# -----------------------------------------------
# avg val loss per batch: 2.729510
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 1.630782  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.939649
# -----------------------------------------------
# avg val loss per batch: 2.226880
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 1.431731  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.366617
# -----------------------------------------------
# avg val loss per batch: 1.664870
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 2.415553  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.142251
# -----------------------------------------------
# avg val loss per batch: 1.396866
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 0.829313  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.050910
# -----------------------------------------------
# avg val loss per batch: 1.246854
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 0.734439  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.904568
# -----------------------------------------------
# avg val loss per batch: 1.096226
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 1.479635  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.813288
# -----------------------------------------------
# avg val loss per batch: 1.005894
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 0.510534  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.750823
# -----------------------------------------------
# avg val loss per batch: 0.939351
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 0.793650  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.702882
# -----------------------------------------------
# avg val loss per batch: 0.880889
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 0.686330  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.676511
# -----------------------------------------------
# avg val loss per batch: 0.829256
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 0.595705  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.649288
# -----------------------------------------------
# avg val loss per batch: 0.796212
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 0.725865  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.611164
# -----------------------------------------------
# avg val loss per batch: 0.756908
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 1.038800  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.575244
# -----------------------------------------------
# avg val loss per batch: 0.727128
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 0.509599  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.554765
# -----------------------------------------------
# avg val loss per batch: 0.706658
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 0.502311  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.532349
# -----------------------------------------------
# avg val loss per batch: 0.682012
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 0.482930  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.522417
# -----------------------------------------------
# avg val loss per batch: 0.659959
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 0.424986  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.503726
# -----------------------------------------------
# avg val loss per batch: 0.648632
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 0.518096  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.537900
# -----------------------------------------------
# avg val loss per batch: 0.708926
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 0.417893  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.484577
# -----------------------------------------------
# avg val loss per batch: 0.637794
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 0.483412  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.467132
# -----------------------------------------------
# avg val loss per batch: 0.598385
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 0.392847  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.459481
# -----------------------------------------------
# avg val loss per batch: 0.601040
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 0.360999  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.453429
# -----------------------------------------------
# avg val loss per batch: 0.597425
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 0.494013  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.450295
# -----------------------------------------------
# avg val loss per batch: 0.607794
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 0.644679  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.426327
# -----------------------------------------------
# avg val loss per batch: 0.570129
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 0.402348  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.448909
# -----------------------------------------------
# avg val loss per batch: 0.571808
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 0.435268  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.425942
# -----------------------------------------------
# avg val loss per batch: 0.550052
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 0.394969  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.406156
# -----------------------------------------------
# avg val loss per batch: 0.549846
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 0.259049  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.399451
# -----------------------------------------------
# avg val loss per batch: 0.541155
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 0.420352  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.406056
# -----------------------------------------------
# avg val loss per batch: 0.566472
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 0.405540  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.392109
# -----------------------------------------------
# avg val loss per batch: 0.527228
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 0.349577  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.379750
# -----------------------------------------------
# avg val loss per batch: 0.523155
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 0.254893  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.378767
# -----------------------------------------------
# avg val loss per batch: 0.521238
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 0.284781  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.370027
# -----------------------------------------------
# avg val loss per batch: 0.514620
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 0.446625  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.372235
# -----------------------------------------------
# avg val loss per batch: 0.507480
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 0.319232  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.376346
# -----------------------------------------------
# avg val loss per batch: 0.505113
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 0.382254  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.360533
# -----------------------------------------------
# avg val loss per batch: 0.504626
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 0.273322  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.364023
# -----------------------------------------------
# avg val loss per batch: 0.523357
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 0.479404  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.352992
# -----------------------------------------------
# avg val loss per batch: 0.502598
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 0.344713  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.358844
# -----------------------------------------------
# avg val loss per batch: 0.490870
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 0.399730  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.342043
# -----------------------------------------------
# avg val loss per batch: 0.489578
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 0.420380  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.343530
# -----------------------------------------------
# avg val loss per batch: 0.486969
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 0.259895  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.358741
# -----------------------------------------------
# avg val loss per batch: 0.492096
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 0.345282  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.338186
# -----------------------------------------------
# avg val loss per batch: 0.510675
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 0.324608  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.326196
# -----------------------------------------------
# avg val loss per batch: 0.481651
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 0.393696  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.327152
# -----------------------------------------------
# avg val loss per batch: 0.477026
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 0.272574  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.320517
# -----------------------------------------------
# avg val loss per batch: 0.477627
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 0.367656  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.327902
# -----------------------------------------------
# avg val loss per batch: 0.476906
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 0.223643  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.315169
# -----------------------------------------------
# avg val loss per batch: 0.483042
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 0.314445  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.321171
# -----------------------------------------------
# avg val loss per batch: 0.494759
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 0.244188  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.316111
# -----------------------------------------------
# avg val loss per batch: 0.472944
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 0.323843  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.339856
# -----------------------------------------------
# avg val loss per batch: 0.524059
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 0.352446  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.322477
# -----------------------------------------------
# avg val loss per batch: 0.505067
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 0.212150  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.311872
# -----------------------------------------------
# avg val loss per batch: 0.462477
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 0.314890  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.299520
# -----------------------------------------------
# avg val loss per batch: 0.466017
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 0.404595  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.296425
# -----------------------------------------------
# avg val loss per batch: 0.461218
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 0.356939  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.295357
# -----------------------------------------------
# avg val loss per batch: 0.451677
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 0.234209  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.304085
# -----------------------------------------------
# avg val loss per batch: 0.455969
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 0.345944  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.294735
# -----------------------------------------------
# avg val loss per batch: 0.455270
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 0.372603  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.307402
# -----------------------------------------------
# avg val loss per batch: 0.493571
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 0.279490  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.305902
# -----------------------------------------------
# avg val loss per batch: 0.455169
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 0.296688  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.285092
# -----------------------------------------------
# avg val loss per batch: 0.455634
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 0.252393  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.286981
# -----------------------------------------------
# avg val loss per batch: 0.447227
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 0.195085  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.281138
# -----------------------------------------------
# avg val loss per batch: 0.456851
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 0.274936  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.288449
# -----------------------------------------------
# avg val loss per batch: 0.446427
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 0.250076  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.282886
# -----------------------------------------------
# avg val loss per batch: 0.461311
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 0.279885  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.291459
# -----------------------------------------------
# avg val loss per batch: 0.451282
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 0.283684  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.273799
# -----------------------------------------------
# avg val loss per batch: 0.442919
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 0.381060  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.303972
# -----------------------------------------------
# avg val loss per batch: 0.498114
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 0.255415  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.277593
# -----------------------------------------------
# avg val loss per batch: 0.444277
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 0.299409  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.284284
# -----------------------------------------------
# avg val loss per batch: 0.469260
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 0.303478  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.360668
# -----------------------------------------------
# avg val loss per batch: 0.507383
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 0.357573  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.275918
# -----------------------------------------------
# avg val loss per batch: 0.470433
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 0.370017  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.282280
# -----------------------------------------------
# avg val loss per batch: 0.445026
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 0.307125  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.345723
# -----------------------------------------------
# avg val loss per batch: 0.561573
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 0.446887  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.315750
# -----------------------------------------------
# avg val loss per batch: 0.472444
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 0.308343  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.269447
# -----------------------------------------------
# avg val loss per batch: 0.462083
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 0.188515  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.282635
# -----------------------------------------------
# avg val loss per batch: 0.443367
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 0.268649  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.257990
# -----------------------------------------------
# avg val loss per batch: 0.438843
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 0.245391  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.259717
# -----------------------------------------------
# avg val loss per batch: 0.438417
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 0.298543  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.270151
# -----------------------------------------------
# avg val loss per batch: 0.438936
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 0.252565  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.270952
# -----------------------------------------------
# avg val loss per batch: 0.473573
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 0.251354  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.282960
# -----------------------------------------------
# avg val loss per batch: 0.442894
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 0.359065  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.252997
# -----------------------------------------------
# avg val loss per batch: 0.431699
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 0.246498  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.257004
# -----------------------------------------------
# avg val loss per batch: 0.445925
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 0.262807  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.295733
# -----------------------------------------------
# avg val loss per batch: 0.509531
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 107
# -----------------------------------------------
# current batch loss: 0.238772  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.283164
# -----------------------------------------------
# avg val loss per batch: 0.447856
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 108
# -----------------------------------------------
# current batch loss: 0.228224  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.251558
# -----------------------------------------------
# avg val loss per batch: 0.430417
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 109
# -----------------------------------------------
# current batch loss: 0.215605  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.249823
# -----------------------------------------------
# avg val loss per batch: 0.441561
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 110
# -----------------------------------------------
# current batch loss: 0.180589  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.247830
# -----------------------------------------------
# avg val loss per batch: 0.430152
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 111
# -----------------------------------------------
# current batch loss: 0.252051  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.244955
# -----------------------------------------------
# avg val loss per batch: 0.434992
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 112
# -----------------------------------------------
# current batch loss: 0.174795  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.246323
# -----------------------------------------------
# avg val loss per batch: 0.436242
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 113
# -----------------------------------------------
# current batch loss: 0.179663  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.252450
# -----------------------------------------------
# avg val loss per batch: 0.427503
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 114
# -----------------------------------------------
# current batch loss: 0.289285  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.242791
# -----------------------------------------------
# avg val loss per batch: 0.429551
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 115
# -----------------------------------------------
# current batch loss: 0.200122  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.246126
# -----------------------------------------------
# avg val loss per batch: 0.451342
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 0.215083  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.243697
# -----------------------------------------------
# avg val loss per batch: 0.430292
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 0.273184  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.254822
# -----------------------------------------------
# avg val loss per batch: 0.463539
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 0.269549  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.237470
# -----------------------------------------------
# avg val loss per batch: 0.429662
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 0.201575  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.238422
# -----------------------------------------------
# avg val loss per batch: 0.427485
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 0.237712  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.265732
# -----------------------------------------------
# avg val loss per batch: 0.479772
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 0.265679  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.250874
# -----------------------------------------------
# avg val loss per batch: 0.462278
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 0.281491  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.244824
# -----------------------------------------------
# avg val loss per batch: 0.424745
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 0.275179  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.242095
# -----------------------------------------------
# avg val loss per batch: 0.429680
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 0.248885  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.244501
# -----------------------------------------------
# avg val loss per batch: 0.449952
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 0.248483  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.234765
# -----------------------------------------------
# avg val loss per batch: 0.434871
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 0.242668  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.287288
# -----------------------------------------------
# avg val loss per batch: 0.454263
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 0.286312  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.296868
# -----------------------------------------------
# avg val loss per batch: 0.534261
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 0.340203  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.238777
# -----------------------------------------------
# avg val loss per batch: 0.423095
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 0.240385  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.245789
# -----------------------------------------------
# avg val loss per batch: 0.424708
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 0.214481  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.248299
# -----------------------------------------------
# avg val loss per batch: 0.466203
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 131
# -----------------------------------------------
# current batch loss: 0.183106  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.225084
# -----------------------------------------------
# avg val loss per batch: 0.423128
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 132
# ...
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 238
# -----------------------------------------------
# current batch loss: 0.166345  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.159127
# -----------------------------------------------
# avg val loss per batch: 0.357996
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 239
# -----------------------------------------------
# current batch loss: 0.138333  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.184869
# -----------------------------------------------
# avg val loss per batch: 0.374139
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 240
# -----------------------------------------------
# current batch loss: 0.189923  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.248541
# -----------------------------------------------
# avg val loss per batch: 0.417719
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 241
# -----------------------------------------------
# current batch loss: 0.197567  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.204371
# -----------------------------------------------
# avg val loss per batch: 0.388449
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 242
# -----------------------------------------------
# current batch loss: 0.224624  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.217901
# -----------------------------------------------
# avg val loss per batch: 0.391383
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 243
# -----------------------------------------------
# current batch loss: 0.242253  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.175830
# -----------------------------------------------
# avg val loss per batch: 0.361897
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 244
# -----------------------------------------------
# current batch loss: 0.212478  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.154023
# -----------------------------------------------
# avg val loss per batch: 0.360346
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 245
# -----------------------------------------------
# current batch loss: 0.137057  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.162543
# -----------------------------------------------
# avg val loss per batch: 0.377332
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 246
# -----------------------------------------------
# current batch loss: 0.178535  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.185546
# -----------------------------------------------
# avg val loss per batch: 0.422158
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 247
# -----------------------------------------------
# current batch loss: 0.203164  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.156991
# -----------------------------------------------
# avg val loss per batch: 0.353861
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 248
# -----------------------------------------------
# current batch loss: 0.155935  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.158644
# -----------------------------------------------
# avg val loss per batch: 0.359803
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 249
# -----------------------------------------------
# current batch loss: 0.160981  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.161129
# -----------------------------------------------
# avg val loss per batch: 0.374776
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 250
# -----------------------------------------------
# current batch loss: 0.119225  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.157612
# -----------------------------------------------
# avg val loss per batch: 0.376522
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 251
# -----------------------------------------------
# current batch loss: 0.116313  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.151262
# -----------------------------------------------
# avg val loss per batch: 0.358482
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 252
# -----------------------------------------------
# current batch loss: 0.106915  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.150733
# -----------------------------------------------
# avg val loss per batch: 0.354628
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 253
# -----------------------------------------------
# current batch loss: 0.203329  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.151295
# -----------------------------------------------
# avg val loss per batch: 0.351338
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 254
# -----------------------------------------------
# current batch loss: 0.201559  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.149020
# -----------------------------------------------
# avg val loss per batch: 0.361155
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 255
# -----------------------------------------------
# current batch loss: 0.118025  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.152087
# -----------------------------------------------
# avg val loss per batch: 0.366097
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 256
# -----------------------------------------------
# current batch loss: 0.204066  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.155733
# -----------------------------------------------
# avg val loss per batch: 0.372691
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 257
# -----------------------------------------------
# current batch loss: 0.152940  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.148679
# -----------------------------------------------
# avg val loss per batch: 0.358135
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 258
# -----------------------------------------------
# current batch loss: 0.165124  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.146261
# -----------------------------------------------
# avg val loss per batch: 0.353819
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 259
# -----------------------------------------------
# current batch loss: 0.109917  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.180076
# -----------------------------------------------
# avg val loss per batch: 0.417071
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 260
# -----------------------------------------------
# current batch loss: 0.131481  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.152520
# -----------------------------------------------
# avg val loss per batch: 0.367704
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 261
# -----------------------------------------------
# current batch loss: 0.117648  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.146170
# -----------------------------------------------
# avg val loss per batch: 0.345701
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 262
# -----------------------------------------------
# current batch loss: 0.108308  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.145148
# -----------------------------------------------
# avg val loss per batch: 0.355319
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 263
# -----------------------------------------------
# current batch loss: 0.094740  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.153917
# -----------------------------------------------
# avg val loss per batch: 0.369963
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 264
# -----------------------------------------------
# current batch loss: 0.125673  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.179328
# -----------------------------------------------
# avg val loss per batch: 0.415463
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 265
# -----------------------------------------------
# current batch loss: 0.145066  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.145199
# -----------------------------------------------
# avg val loss per batch: 0.352187
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 266
# -----------------------------------------------
# current batch loss: 0.209300  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.143418
# -----------------------------------------------
# avg val loss per batch: 0.347783
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 267
# -----------------------------------------------
# current batch loss: 0.193607  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.142203
# -----------------------------------------------
# avg val loss per batch: 0.352528
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 268
# -----------------------------------------------
# current batch loss: 0.139242  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.158633
# -----------------------------------------------
# avg val loss per batch: 0.349141
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 269
# -----------------------------------------------
# current batch loss: 0.154167  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.144546
# -----------------------------------------------
# avg val loss per batch: 0.339946
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 270
# -----------------------------------------------
# current batch loss: 0.179715  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.144513
# -----------------------------------------------
# avg val loss per batch: 0.358384
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 271
# -----------------------------------------------
# current batch loss: 0.153017  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.142046
# -----------------------------------------------
# avg val loss per batch: 0.350492
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 272
# -----------------------------------------------
# current batch loss: 0.119082  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.167320
# -----------------------------------------------
# avg val loss per batch: 0.398407
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 273
# -----------------------------------------------
# current batch loss: 0.206281  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.140176
# -----------------------------------------------
# avg val loss per batch: 0.344730
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 274
# -----------------------------------------------
# current batch loss: 0.109350  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.153480
# -----------------------------------------------
# avg val loss per batch: 0.376236
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 275
# -----------------------------------------------
# current batch loss: 0.141471  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.140371
# -----------------------------------------------
# avg val loss per batch: 0.346898
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 276
# -----------------------------------------------
# current batch loss: 0.111924  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.143199
# -----------------------------------------------
# avg val loss per batch: 0.362375
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 277
# -----------------------------------------------
# current batch loss: 0.150389  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.150628
# -----------------------------------------------
# avg val loss per batch: 0.336350
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 278
# -----------------------------------------------
# current batch loss: 0.119048  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.141973
# -----------------------------------------------
# avg val loss per batch: 0.337652
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 279
# -----------------------------------------------
# current batch loss: 0.189945  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.137380
# -----------------------------------------------
# avg val loss per batch: 0.341914
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 280
# -----------------------------------------------
# current batch loss: 0.124114  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.138805
# -----------------------------------------------
# avg val loss per batch: 0.345999
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 281
# -----------------------------------------------
# current batch loss: 0.125261  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.149414
# -----------------------------------------------
# avg val loss per batch: 0.376717
# EarlyStopping got triggered! Stop training!
# Done!

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses_es, label="train loss", color=c1 )
axs.plot( val_losses_es, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = [ int(x) for x in axs.get_xticks() ]
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# We can see here that the network has stopped training before the training loss diverges too far from the validation loss.

# %% [markdown]
# ### Batch normalisation

# %% [markdown]
# Batch normalisation is not a method to prevent over-fitting, so we do not expect it to do that.  The point of batch normalisation is to make the training more efficient.  It's difficult to see the benefits of this regularisation method with the dataset we're using here, although it is still useful to learn how to implement it.  It works by normalising the data as it passes between the layers, keeping the distribution (i.e. mean and variance) of the data constant throughout training.  This means that the weights in a network layer do not have to adapt to simple changes in the distribution of the data in a previous layer of the network.

# %%
class amp_net_bn( nn.Module ):
    
    # default hdn_dim is 30, but can be changed upon initialisation
    def __init__( self, hdn_dim=30 ):
        
        super( amp_net_bn, self ).__init__()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear( ipt_dim, hdn_dim ),
            nn.BatchNorm1d(hdn_dim),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.BatchNorm1d(hdn_dim),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.BatchNorm1d(hdn_dim),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.BatchNorm1d(hdn_dim),
            nn.ReLU(),
            nn.Linear( hdn_dim, opt_dim ),
        )

    def forward( self, x ):
        out = self.linear_relu_stack( x )
        return out

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# define parameters
ipt_dim = 20
opt_dim = 1
hdn_dim = 50
batch_size = 64
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 1500

# re-initialise the model and the optimizer
hdn_dim = 50
model_bn = amp_net_bn( hdn_dim=hdn_dim ).to(device)
learning_rate = 5e-4

optimizer = torch.optim.Adam( model_bn.parameters(), lr=learning_rate)

# %%
seperator()
print( "model architecture ")
seperator()
print( model_bn )

# track train and val losses
trn_losses_bn = []
val_losses_bn = []

# set counter to 0 for early stopping
trigger_counter = 0
val_loss_last = 1e10
for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model_bn, loss_fn, optimizer )
    seperator()
    model_bn.eval()
    trn_loss = trn_pass( trn_dataloader, model_bn, loss_fn )
    trn_losses_bn.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model_bn, loss_fn )
    val_losses_bn.append( val_loss )
    model_bn.train()
    
    seperator()
    print( "|" )
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net_bn(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=50, out_features=50, bias=True)
#     (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=50, out_features=50, bias=True)
#     (7): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Linear(in_features=50, out_features=50, bias=True)
#     (10): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#     (12): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 215.589111  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 214.507314
# -----------------------------------------------
# avg val loss per batch: 216.849586
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 207.944290  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 208.435224
# -----------------------------------------------
# avg val loss per batch: 210.488757
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 198.394440  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 198.997242
# -----------------------------------------------
# avg val loss per batch: 200.835264
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 196.266296  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 192.363064
# -----------------------------------------------
# avg val loss per batch: 194.015926
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 193.162964  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 187.034052
# -----------------------------------------------
# avg val loss per batch: 188.851682
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 185.937866  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 179.875360
# -----------------------------------------------
# avg val loss per batch: 181.851384
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 182.622116  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 173.669636
# -----------------------------------------------
# avg val loss per batch: 175.496115
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 174.565216  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 168.302924
# -----------------------------------------------
# avg val loss per batch: 170.106743
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 168.466812  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 162.740374
# -----------------------------------------------
# avg val loss per batch: 164.589264
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 165.605423  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 158.650936
# -----------------------------------------------
# avg val loss per batch: 160.322328
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 157.479813  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 153.126192
# -----------------------------------------------
# avg val loss per batch: 154.879470
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 150.101837  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 146.758298
# -----------------------------------------------
# avg val loss per batch: 148.603436
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 146.631729  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 140.782559
# -----------------------------------------------
# avg val loss per batch: 142.315475
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 135.663055  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 135.856807
# -----------------------------------------------
# avg val loss per batch: 137.556150
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 136.053696  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 129.573267
# -----------------------------------------------
# avg val loss per batch: 131.367108
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 128.037384  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 123.627320
# -----------------------------------------------
# avg val loss per batch: 125.544417
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 120.771942  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 118.419525
# -----------------------------------------------
# avg val loss per batch: 120.544718
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 113.739624  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 113.669949
# -----------------------------------------------
# avg val loss per batch: 115.697391
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 105.720413  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 106.857295
# -----------------------------------------------
# avg val loss per batch: 108.589749
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 101.547562  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 102.168817
# -----------------------------------------------
# avg val loss per batch: 103.923446
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 98.079193  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 96.885215
# -----------------------------------------------
# avg val loss per batch: 98.686515
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 94.821541  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 90.831423
# -----------------------------------------------
# avg val loss per batch: 92.701930
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 91.051590  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 85.288134
# -----------------------------------------------
# avg val loss per batch: 87.149178
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 82.596840  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 79.537687
# -----------------------------------------------
# avg val loss per batch: 81.595302
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 79.753624  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 73.651173
# -----------------------------------------------
# avg val loss per batch: 75.504414
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 75.763275  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 68.861208
# -----------------------------------------------
# avg val loss per batch: 70.830085
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 66.036568  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 63.837394
# -----------------------------------------------
# avg val loss per batch: 65.669550
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 59.971428  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 56.480131
# -----------------------------------------------
# avg val loss per batch: 58.251673
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 52.654701  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 52.953572
# -----------------------------------------------
# avg val loss per batch: 54.947900
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 50.314316  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 48.407975
# -----------------------------------------------
# avg val loss per batch: 50.250544
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 43.934757  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 43.192634
# -----------------------------------------------
# avg val loss per batch: 44.893759
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 39.585209  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 39.415483
# -----------------------------------------------
# avg val loss per batch: 41.156342
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 37.156296  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 34.634343
# -----------------------------------------------
# avg val loss per batch: 36.312278
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 32.682114  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 31.399103
# -----------------------------------------------
# avg val loss per batch: 33.049098
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 27.630470  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 27.932429
# -----------------------------------------------
# avg val loss per batch: 29.538679
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 24.216064  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 24.181269
# -----------------------------------------------
# avg val loss per batch: 25.678251
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 21.467587  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 21.664499
# -----------------------------------------------
# avg val loss per batch: 23.127465
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 20.034157  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 19.052691
# -----------------------------------------------
# avg val loss per batch: 20.451657
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 17.295788  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 16.185400
# -----------------------------------------------
# avg val loss per batch: 17.520134
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 15.563190  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 14.057584
# -----------------------------------------------
# avg val loss per batch: 15.180493
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 12.615708  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 12.465846
# -----------------------------------------------
# avg val loss per batch: 13.667684
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 9.795603  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 10.571690
# -----------------------------------------------
# avg val loss per batch: 11.558901
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 9.506160  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 8.742954
# -----------------------------------------------
# avg val loss per batch: 9.766820
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 6.962748  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 7.284942
# -----------------------------------------------
# avg val loss per batch: 8.171044
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 6.938852  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 6.519187
# -----------------------------------------------
# avg val loss per batch: 7.466323
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 5.359044  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 5.301050
# -----------------------------------------------
# avg val loss per batch: 5.995844
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 5.389345  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 4.694737
# -----------------------------------------------
# avg val loss per batch: 5.352552
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 3.682803  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.862807
# -----------------------------------------------
# avg val loss per batch: 4.546564
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 3.170337  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 3.469187
# -----------------------------------------------
# avg val loss per batch: 4.022726
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 2.935951  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.623424
# -----------------------------------------------
# avg val loss per batch: 3.118696
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 2.759817  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 2.301770
# -----------------------------------------------
# avg val loss per batch: 2.770590
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 1.708478  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.784872
# -----------------------------------------------
# avg val loss per batch: 2.248559
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 1.623029  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.607150
# -----------------------------------------------
# avg val loss per batch: 1.985822
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 1.126073  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.402658
# -----------------------------------------------
# avg val loss per batch: 1.822419
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 1.205890  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 1.176625
# -----------------------------------------------
# avg val loss per batch: 1.567566
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 0.975262  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.831974
# -----------------------------------------------
# avg val loss per batch: 1.151070
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 1.020469  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.842034
# -----------------------------------------------
# avg val loss per batch: 1.162113
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 0.830705  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.865527
# -----------------------------------------------
# avg val loss per batch: 1.182657
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 0.984717  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.668377
# -----------------------------------------------
# avg val loss per batch: 0.974638
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 0.696520  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.573062
# -----------------------------------------------
# avg val loss per batch: 0.850437
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 0.453115  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.563778
# -----------------------------------------------
# avg val loss per batch: 0.859589
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 0.337393  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.476963
# -----------------------------------------------
# avg val loss per batch: 0.738074
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 0.663777  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.484069
# -----------------------------------------------
# avg val loss per batch: 0.767867
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 0.602785  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.351211
# -----------------------------------------------
# avg val loss per batch: 0.583343
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 0.394578  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.352739
# -----------------------------------------------
# avg val loss per batch: 0.566680
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 0.371374  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.345821
# -----------------------------------------------
# avg val loss per batch: 0.577823
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 0.342081  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.293601
# -----------------------------------------------
# avg val loss per batch: 0.525881
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 0.540851  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.364275
# -----------------------------------------------
# avg val loss per batch: 0.610866
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 0.629191  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.265171
# -----------------------------------------------
# avg val loss per batch: 0.507237
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 0.395414  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.258658
# -----------------------------------------------
# avg val loss per batch: 0.500241
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 0.199027  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.245357
# -----------------------------------------------
# avg val loss per batch: 0.476021
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 0.542436  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.271427
# -----------------------------------------------
# avg val loss per batch: 0.478681
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 0.364514  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.249742
# -----------------------------------------------
# avg val loss per batch: 0.479662
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 0.352210  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.276728
# -----------------------------------------------
# avg val loss per batch: 0.521659
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 0.251847  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.233830
# -----------------------------------------------
# avg val loss per batch: 0.455369
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 0.458385  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.265858
# -----------------------------------------------
# avg val loss per batch: 0.480019
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 0.310203  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.214891
# -----------------------------------------------
# avg val loss per batch: 0.415273
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 0.205712  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.232566
# -----------------------------------------------
# avg val loss per batch: 0.429423
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 0.350665  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.205136
# -----------------------------------------------
# avg val loss per batch: 0.411298
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 0.350667  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.181242
# -----------------------------------------------
# avg val loss per batch: 0.389152
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 0.325492  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.200430
# -----------------------------------------------
# avg val loss per batch: 0.422380
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 0.446510  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.176419
# -----------------------------------------------
# avg val loss per batch: 0.414538
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 0.297513  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.185299
# -----------------------------------------------
# avg val loss per batch: 0.421983
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 0.432819  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.190981
# -----------------------------------------------
# avg val loss per batch: 0.396144
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 0.194942  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.224066
# -----------------------------------------------
# avg val loss per batch: 0.427866
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 0.352461  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.194457
# -----------------------------------------------
# avg val loss per batch: 0.409984
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 0.389056  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.193236
# -----------------------------------------------
# avg val loss per batch: 0.406622
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 0.285270  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.196775
# -----------------------------------------------
# avg val loss per batch: 0.401195
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 0.518234  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.156230
# -----------------------------------------------
# avg val loss per batch: 0.361175
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 0.205554  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.161017
# -----------------------------------------------
# avg val loss per batch: 0.362640
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 0.335644  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.160360
# -----------------------------------------------
# avg val loss per batch: 0.367158
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 0.231133  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.164582
# -----------------------------------------------
# avg val loss per batch: 0.380609
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 0.151691  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.155969
# -----------------------------------------------
# avg val loss per batch: 0.351973
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 0.365629  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.150866
# -----------------------------------------------
# avg val loss per batch: 0.349726
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 0.217926  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.175749
# -----------------------------------------------
# avg val loss per batch: 0.383583
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 0.195715  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.148453
# -----------------------------------------------
# avg val loss per batch: 0.363722
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 0.263232  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.167793
# -----------------------------------------------
# avg val loss per batch: 0.372770
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 0.231626  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.154085
# -----------------------------------------------
# avg val loss per batch: 0.351201
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 0.381964  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.156051
# -----------------------------------------------
# avg val loss per batch: 0.356518
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 0.224500  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.142296
# -----------------------------------------------
# avg val loss per batch: 0.338452
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 0.307684  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.135753
# -----------------------------------------------
# avg val loss per batch: 0.343365
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 0.330637  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.152082
# -----------------------------------------------
# avg val loss per batch: 0.362500
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 0.317271  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.177309
# -----------------------------------------------
# avg val loss per batch: 0.372650
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 0.267666  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.161347
# -----------------------------------------------
# avg val loss per batch: 0.358241
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 0.241633  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.130935
# -----------------------------------------------
# avg val loss per batch: 0.330748
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 0.177814  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.142174
# -----------------------------------------------
# avg val loss per batch: 0.354911
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 107
# -----------------------------------------------
# current batch loss: 0.172733  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.121919
# -----------------------------------------------
# avg val loss per batch: 0.328507
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 108
# -----------------------------------------------
# current batch loss: 0.348658  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.119529
# -----------------------------------------------
# avg val loss per batch: 0.332890
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 109
# -----------------------------------------------
# current batch loss: 0.187061  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.133617
# -----------------------------------------------
# avg val loss per batch: 0.339238
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 110
# -----------------------------------------------
# current batch loss: 0.153007  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.142516
# -----------------------------------------------
# avg val loss per batch: 0.356418
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 111
# -----------------------------------------------
# current batch loss: 0.288170  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.135960
# -----------------------------------------------
# avg val loss per batch: 0.355507
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 112
# -----------------------------------------------
# current batch loss: 0.185904  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.123717
# -----------------------------------------------
# avg val loss per batch: 0.330977
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 113
# -----------------------------------------------
# current batch loss: 0.210489  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.150154
# -----------------------------------------------
# avg val loss per batch: 0.350060
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 114
# -----------------------------------------------
# current batch loss: 0.233686  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.129368
# -----------------------------------------------
# avg val loss per batch: 0.317697
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 115
# -----------------------------------------------
# current batch loss: 0.195417  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.123853
# -----------------------------------------------
# avg val loss per batch: 0.322722
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 0.274223  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.107643
# -----------------------------------------------
# avg val loss per batch: 0.301873
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 0.351167  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.118898
# -----------------------------------------------
# avg val loss per batch: 0.324090
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 0.232845  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.119503
# -----------------------------------------------
# avg val loss per batch: 0.321521
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 0.198604  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.147955
# -----------------------------------------------
# avg val loss per batch: 0.342809
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 0.332201  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.109898
# -----------------------------------------------
# avg val loss per batch: 0.307430
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 0.262358  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.129251
# -----------------------------------------------
# avg val loss per batch: 0.313251
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 0.284106  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.106046
# -----------------------------------------------
# avg val loss per batch: 0.298297
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 0.186231  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.123274
# -----------------------------------------------
# avg val loss per batch: 0.337201
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 0.251677  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.115074
# -----------------------------------------------
# avg val loss per batch: 0.313941
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 0.344169  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.115878
# -----------------------------------------------
# avg val loss per batch: 0.315757
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 0.141344  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.098653
# -----------------------------------------------
# avg val loss per batch: 0.289113
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 0.268957  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.106917
# -----------------------------------------------
# avg val loss per batch: 0.299809
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 0.254762  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.110676
# -----------------------------------------------
# avg val loss per batch: 0.304587
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 0.250920  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.111483
# -----------------------------------------------
# avg val loss per batch: 0.293973
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 0.307587  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.094358
# -----------------------------------------------
# avg val loss per batch: 0.274085
# ...
# |
# -----------------------------------------------
# Epoch 1457
# -----------------------------------------------
# current batch loss: 0.022440  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.057703
# -----------------------------------------------
# avg val loss per batch: 0.188270
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1458
# -----------------------------------------------
# current batch loss: 0.080923  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.032797
# -----------------------------------------------
# avg val loss per batch: 0.160369
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1459
# -----------------------------------------------
# current batch loss: 0.050568  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.026887
# -----------------------------------------------
# avg val loss per batch: 0.158197
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1460
# -----------------------------------------------
# current batch loss: 0.032517  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.028443
# -----------------------------------------------
# avg val loss per batch: 0.149995
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1461
# -----------------------------------------------
# current batch loss: 0.051674  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.049646
# -----------------------------------------------
# avg val loss per batch: 0.176693
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1462
# -----------------------------------------------
# current batch loss: 0.047395  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.038009
# -----------------------------------------------
# avg val loss per batch: 0.172266
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1463
# -----------------------------------------------
# current batch loss: 0.051505  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.044070
# -----------------------------------------------
# avg val loss per batch: 0.179013
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1464
# -----------------------------------------------
# current batch loss: 0.035063  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.035149
# -----------------------------------------------
# avg val loss per batch: 0.166874
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1465
# -----------------------------------------------
# current batch loss: 0.040119  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.034546
# -----------------------------------------------
# avg val loss per batch: 0.172352
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1466
# -----------------------------------------------
# current batch loss: 0.072240  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.025768
# -----------------------------------------------
# avg val loss per batch: 0.154459
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1467
# -----------------------------------------------
# current batch loss: 0.057645  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.043805
# -----------------------------------------------
# avg val loss per batch: 0.174806
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1468
# -----------------------------------------------
# current batch loss: 0.043368  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.031895
# -----------------------------------------------
# avg val loss per batch: 0.166106
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1469
# -----------------------------------------------
# current batch loss: 0.035476  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.065687
# -----------------------------------------------
# avg val loss per batch: 0.200479
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1470
# -----------------------------------------------
# current batch loss: 0.052090  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.053706
# -----------------------------------------------
# avg val loss per batch: 0.185994
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1471
# -----------------------------------------------
# current batch loss: 0.041328  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.032292
# -----------------------------------------------
# avg val loss per batch: 0.162715
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1472
# -----------------------------------------------
# current batch loss: 0.032153  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.047451
# -----------------------------------------------
# avg val loss per batch: 0.176141
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1473
# -----------------------------------------------
# current batch loss: 0.056690  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.039057
# -----------------------------------------------
# avg val loss per batch: 0.166830
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1474
# -----------------------------------------------
# current batch loss: 0.050473  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.059019
# -----------------------------------------------
# avg val loss per batch: 0.187096
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1475
# -----------------------------------------------
# current batch loss: 0.047994  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.058494
# -----------------------------------------------
# avg val loss per batch: 0.186708
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1476
# -----------------------------------------------
# current batch loss: 0.028104  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.053174
# -----------------------------------------------
# avg val loss per batch: 0.181416
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1477
# -----------------------------------------------
# current batch loss: 0.038701  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.035720
# -----------------------------------------------
# avg val loss per batch: 0.164653
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1478
# -----------------------------------------------
# current batch loss: 0.052716  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.027833
# -----------------------------------------------
# avg val loss per batch: 0.154357
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1479
# -----------------------------------------------
# current batch loss: 0.063053  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.028798
# -----------------------------------------------
# avg val loss per batch: 0.151300
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1480
# -----------------------------------------------
# current batch loss: 0.060878  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.061957
# -----------------------------------------------
# avg val loss per batch: 0.190943
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1481
# -----------------------------------------------
# current batch loss: 0.080300  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.052434
# -----------------------------------------------
# avg val loss per batch: 0.185077
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1482
# -----------------------------------------------
# current batch loss: 0.037972  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.049238
# -----------------------------------------------
# avg val loss per batch: 0.187945
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1483
# -----------------------------------------------
# current batch loss: 0.127173  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.069821
# -----------------------------------------------
# avg val loss per batch: 0.206124
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1484
# -----------------------------------------------
# current batch loss: 0.029894  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.030554
# -----------------------------------------------
# avg val loss per batch: 0.159888
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1485
# -----------------------------------------------
# current batch loss: 0.051042  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.072631
# -----------------------------------------------
# avg val loss per batch: 0.202667
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1486
# -----------------------------------------------
# current batch loss: 0.046388  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.065395
# -----------------------------------------------
# avg val loss per batch: 0.199073
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1487
# -----------------------------------------------
# current batch loss: 0.066942  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.053425
# -----------------------------------------------
# avg val loss per batch: 0.188795
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1488
# -----------------------------------------------
# current batch loss: 0.034387  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.028950
# -----------------------------------------------
# avg val loss per batch: 0.158355
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1489
# -----------------------------------------------
# current batch loss: 0.061302  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.028136
# -----------------------------------------------
# avg val loss per batch: 0.160450
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1490
# -----------------------------------------------
# current batch loss: 0.024131  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.046768
# -----------------------------------------------
# avg val loss per batch: 0.176509
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1491
# -----------------------------------------------
# current batch loss: 0.027196  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.029607
# -----------------------------------------------
# avg val loss per batch: 0.156696
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1492
# -----------------------------------------------
# current batch loss: 0.018598  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.041184
# -----------------------------------------------
# avg val loss per batch: 0.176194
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1493
# -----------------------------------------------
# current batch loss: 0.033925  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.045423
# -----------------------------------------------
# avg val loss per batch: 0.171705
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1494
# -----------------------------------------------
# current batch loss: 0.072467  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.043857
# -----------------------------------------------
# avg val loss per batch: 0.172270
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1495
# -----------------------------------------------
# current batch loss: 0.071797  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.026890
# -----------------------------------------------
# avg val loss per batch: 0.149968
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1496
# -----------------------------------------------
# current batch loss: 0.038928  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.026055
# -----------------------------------------------
# avg val loss per batch: 0.156694
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1497
# -----------------------------------------------
# current batch loss: 0.039649  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.062488
# -----------------------------------------------
# avg val loss per batch: 0.194141
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1498
# -----------------------------------------------
# current batch loss: 0.028819  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.064148
# -----------------------------------------------
# avg val loss per batch: 0.197828
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1499
# -----------------------------------------------
# current batch loss: 0.028954  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.025348
# -----------------------------------------------
# avg val loss per batch: 0.149791
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 1500
# -----------------------------------------------
# current batch loss: 0.032466  [    0/ 1000]
# -----------------------------------------------
# avg trn loss per batch: 0.053264
# -----------------------------------------------
# avg val loss per batch: 0.181153
# -----------------------------------------------
# |
# Done!

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses_bn, label="train loss", color=c1 )
axs.plot( val_losses_bn, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = [ int(x) for x in axs.get_xticks() ]
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# As expected, this has not solved the over-fitting problem, but at least you now know how to implement batch norm!

# %% [markdown]
# ### Using combinations of these methods

# %% [markdown]
# Here we have looked at each of these regularisation methods individually, however they work best when used together.  For example you could use either dropout or L2 regularisation to stop your network overfitting, then use early stopping to stop the training when the loss has converged.  This way we do not waste computational resources after our network has converged.  We could then make even better use of our computational resources by introducing batch normalisation.
#
# We note that often to get these methods working as you want them to, some research has to be done to find the best hyper-parameters, e.g. the $p$ parameter in dropout, the weight-decay in L2 regularisation, or the patience in early stopping.
